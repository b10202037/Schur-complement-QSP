# %%
import matplotlib.pyplot as plt
import openfermion as of
from Hubbard_Model_nnn import *
import jax.numpy as jnp
from itertools import product
from jax import config
from numpy.polynomial.chebyshev import Chebyshev
from scipy.io import loadmat
import scipy.sparse as sp
import glob
config.update("jax_enable_x64", True)

# %% [markdown]
# # Set parameters.

# %%
# Parameters.
x_dimension = 3
y_dimension = 3
n_up = 2
n_down = 2

n_site = x_dimension * y_dimension

U = 2
t = 1.0
t_prime = 0.3
mu = 0.0

# %% [markdown]
# ## Construct the reduced Hamiltonian.

# %%
def reduced_hubbard_model(U, indices):
    hopping_terms = fermi_hubbard_nnn(x_dimension, y_dimension, tunneling=t, nnn_tunneling=t_prime, coulomb=U, chemical_potential=mu, periodic=True)
    hopping_terms = of.get_sparse_operator(hopping_terms)
    H_hubbard = hopping_terms[jnp.ix_(indices, indices)].toarray()

    return H_hubbard

# %%
valid_indices = []
for bits in product('01', repeat= 2 * x_dimension * y_dimension):

    spin_up_indices = bits[::2]
    spin_down_indices = bits[1::2]

    if spin_up_indices.count('1') == n_up and spin_down_indices.count('1') == n_down:
        binary_str = ''.join(bits)
        valid_indices.append(int(binary_str, 2))

reduced_H_indices = jnp.array(valid_indices)

H_reduced = reduced_hubbard_model(U=U, indices=reduced_H_indices)
reduced_dim = len(H_reduced)
print('reduced_dim =', reduced_dim)

H_reduced_eigvals, H_reduced_eigvecs = jnp.linalg.eigh(H_reduced)
print(f"Eigenvalues:", jnp.round(H_reduced_eigvals[:8], 3))
# Out:
# reduced_dim = 1296
# Eigenvalues: [-10.645 -10.633 -10.633 -10.633 -10.633 -10.628 -10.628 -10.503]

# %%
U_sweep_ED = jnp.linspace(0, U, 80)

H_eigvals_sweep = []

for UU in U_sweep_ED:
    H = reduced_hubbard_model(U=float(UU), indices=reduced_H_indices)
    eigvals = jnp.linalg.eigvalsh(H)
    H_eigvals_sweep.append(eigvals)

H_eigvals_sweep = jnp.array(H_eigvals_sweep).T

# %%
for band in range(16):
    plt.plot(U_sweep_ED, H_eigvals_sweep[band], 'red')


plt.xlabel('U')
plt.ylabel('E')
plt.title(f'Eigenvalues vs U, {x_dimension}x{y_dimension}')
# plt.ylim(jnp.min(solved_eigvals) - 0.5, jnp.max(solved_eigvals) + 0.5)

# plt.legend()
plt.show()

# %% [markdown]
# # Schur complement

# %%
def find_degeneracies(E0, tol=1E-10):

    sorted_indices = jnp.argsort(E0)
    sorted_E0 = jnp.array(E0)[sorted_indices]
    
    degeneracy_counts = []

    current_degeneracy = 1

    for i in range(1, len(sorted_E0)):
        if jnp.abs(sorted_E0[i] - sorted_E0[i - 1]) < tol:

            current_degeneracy += 1
        else:

            degeneracy_counts.append(current_degeneracy)
            current_degeneracy = 1

    degeneracy_counts.append(current_degeneracy)
    
    return degeneracy_counts

def degenerate_states(Hi, H0_eigvecs, degeneracy_counts):

    start_index = 0
    for i, count in enumerate(degeneracy_counts):
        
        P = H0_eigvecs[:, start_index:start_index+count]
        P_T = jnp.conj(P.T)
        Hi_proj = P_T @ Hi @ P

        Hi_eigvals, Hi_eigvecs = jnp.linalg.eigh(Hi_proj)
        Hi_eigvecs = P @ Hi_eigvecs
        
        if i == 0:
            print("Eigenvalues of first Hi: \n", Hi_eigvals)
        
        H0_eigvecs = H0_eigvecs.at[:, start_index:start_index + count].set(Hi_eigvecs)
        start_index += count

    return H0_eigvecs

# %%
H0 =  reduced_hubbard_model(U=0, indices=reduced_H_indices)

H0_eigvals, H0_eigvecs = jnp.linalg.eigh(H0)
print("Eigenvalues of H0: \n", jnp.round(H0_eigvals[:8], 3))

Hi = reduced_hubbard_model(U=1, indices=reduced_H_indices) - H0
# Out:
# Eigenvalues of H0:
#  [-11.2 -11.2 -11.2 -11.2 -11.2 -11.2 -11.2 -11.2]

# %%
degeneracy_counts = find_degeneracies(H0_eigvals[:], tol=1E-10)
print("Number of degerate Eigenvalues:\n", degeneracy_counts)
k = sum(degeneracy_counts[:1])

degeneracy_counts = find_degeneracies(H0_eigvals[:k], tol=1E-10)
print("Number of degerate Eigenvalues:\n", degeneracy_counts)
H0_eigvecs_updated = degenerate_states(Hi, H0_eigvecs[:, :k], degeneracy_counts)
H0_eigvals_updated = H0_eigvals[:k]

degeneracy_idx = [0, k-1]
degeneracy_dim = degeneracy_idx[1] - degeneracy_idx[0] + 1
# Out:
# Number of degerate Eigenvalues:
#  [16, 32, 16, 48, 176, 176, 36, 48, 192, 328, 192, 36]
# Number of degerate Eigenvalues:
#  [16]
# Eigenvalues of first Hi:
#  [0.33333333 0.33333333 0.33333333 0.33333333 0.33333333 0.33333333
#  0.33333333 0.44444444 0.44444444 0.44444444 0.44444444 0.55555556
#  0.55555556 0.55555556 0.55555556 0.77777778]

# %%
k = 7
H0_eigvecs_updated = H0_eigvecs_updated[:, :k]
H0_eigvals_updated = H0_eigvals[:k]

degeneracy_idx = [0, k-1]
degeneracy_dim = degeneracy_idx[1] - degeneracy_idx[0] + 1

# %%
def Schur_complement(H, E, init_eigvecs, degeneracy_idx, dim):
    degeneracy_dim = degeneracy_idx[1] - degeneracy_idx[0] + 1
    degeneracy_eigvecs = init_eigvecs[:, degeneracy_idx[0]:degeneracy_idx[1] + 1]
    Hij = jnp.conj(degeneracy_eigvecs.T) @ H @ degeneracy_eigvecs

    alpha = 1
    gamma = 1E-10
    
    O = jnp.zeros((dim, dim))
    for d in range(degeneracy_dim):
        O += jnp.outer(degeneracy_eigvecs[:, d], jnp.conj(degeneracy_eigvecs[:, d]))
    Q = jnp.eye(dim) - O
    M = alpha * O + Q @ (E * jnp.eye(dim) - H) @ Q + gamma * 1j * jnp.eye(dim)

    # C = O @ H @ O
    # print(jnp.linalg.det(C-H))
    M_inv = jnp.linalg.inv(M)

    Rij = jnp.conj(degeneracy_eigvecs.T) @ H @ Q @ M_inv @ Q @ H @ degeneracy_eigvecs

    return jnp.real(Hij + Rij - E * jnp.eye(degeneracy_dim))

# %%
def Schur_complement_qsp(H, E, init_eigvecs, degeneracy_idx, dim, poly, kappa):
    degeneracy_dim = degeneracy_idx[1] - degeneracy_idx[0] + 1
    degeneracy_eigvecs = init_eigvecs[:, degeneracy_idx[0]:degeneracy_idx[1] + 1]
    Hij = jnp.conj(degeneracy_eigvecs.T) @ H @ degeneracy_eigvecs

    alpha = 1
    gamma = 1E-10
    
    O = jnp.zeros((dim, dim))
    for d in range(degeneracy_dim):
        O += jnp.outer(degeneracy_eigvecs[:, d], jnp.conj(degeneracy_eigvecs[:, d]))
    Q = jnp.eye(dim) - O
    M = alpha * O + Q @ (E * jnp.eye(dim) - H) @ Q + gamma * 1j * jnp.eye(dim)

    N = jnp.linalg.norm(M)
    M = M / N
    
    M_eigvals, M_eigvecs = jnp.linalg.eigh(M)
    M_eigvals_inv = jnp.diag(poly(M_eigvals))
    M_inv = M_eigvecs @ M_eigvals_inv @ jnp.conj(M_eigvecs.T) * 2 * kappa / N

    Rij = jnp.conj(degeneracy_eigvecs.T) @ H @ Q @ M_inv @ Q @ H @ degeneracy_eigvecs

    return jnp.real(Hij + Rij - E * jnp.eye(degeneracy_dim))

# %%
def QHQ_spectrum(H, init_eigvecs, degeneracy_idx, dim):
    degeneracy_dim = degeneracy_idx[1] - degeneracy_idx[0] + 1
    degeneracy_eigvecs = init_eigvecs[:, degeneracy_idx[0]:degeneracy_idx[1] + 1]
    
    O = jnp.zeros((dim, dim))
    for d in range(degeneracy_dim):
        O += jnp.outer(degeneracy_eigvecs[:, d], jnp.conj(degeneracy_eigvecs[:, d]))
    Q = jnp.eye(dim) - O
    QHQ = Q @ H @ Q

    spectrum = jnp.linalg.eigh(QHQ)

    return spectrum

# %%
QHQ_eigvals, QHQ_eigvecs = QHQ_spectrum(H=H_reduced, init_eigvecs=H0_eigvecs_updated, degeneracy_idx=degeneracy_idx, dim=reduced_dim)

# %% [markdown]
# ## Eigenbranches (error $ = 10^{-3}$)

# %%
kappa = 80
error = 3
file_name = f'coef_kappa{kappa}_error1e-{error}*'
file = glob.glob(file_name)
pcoefs = loadmat(file[0])
pcoefs = pcoefs['coef_full']

pcoefs = jnp.array([coef[0] for coef in pcoefs])
poly = Chebyshev(pcoefs)

# %%
Xlim = [H_reduced_eigvals[0] - 0.1, H_reduced_eigvals[10] + 0.1]
N_plot = 100
Energy = jnp.linspace(Xlim[0], Xlim[1], N_plot)

# %%
Eigenbranches = []
for En in Energy:
    Schur = Schur_complement_qsp(H=H_reduced, E=En, init_eigvecs=H0_eigvecs_updated, degeneracy_idx=degeneracy_idx, dim=reduced_dim, poly=poly, kappa=kappa)
    sub_eigvals = jnp.linalg.eigvalsh(Schur)
    Eigenbranches.append(sub_eigvals)
Eigenbranches = jnp.array(Eigenbranches).T

# %%
plt.xlabel('E')
plt.ylabel('Eigenspectrum of Heff')
plt.xlim(Xlim[0], Xlim[1])
# plt.xlim(4, 7)
plt.ylim(-1, 1)

for Eigenbranch in Eigenbranches:
    plt.plot(Energy, Eigenbranch, 'red')

plt.axhline(y=0, color='blue')

plt.plot(H_reduced_eigvals, jnp.zeros_like(H_reduced_eigvals), 'o', color='black')
plt.plot(QHQ_eigvals, jnp.zeros_like(QHQ_eigvals), 'o', color='green', markersize=3)

plt.show()

# %% [markdown]
# # Binary search
# ### ($\Delta U = 0.2$)

# %% [markdown]
# ## error $ = 10^{-3}$

# %%
kappa = 80
error = 3
file_name = f'coef_kappa{kappa}_error1e-{error}*'
file = glob.glob(file_name)
pcoefs = loadmat(file[0])
pcoefs = pcoefs['coef_full']

pcoefs = jnp.array([coef[0] for coef in pcoefs])
poly = Chebyshev(pcoefs)

# %%
U_sweep = jnp.linspace(0, U, 11)

# %%
solved_eigvals = [[vals.item() for vals in H0_eigvals_updated]]

def binary_search_solver(Schur_complement, x0, subspace_eigvals_idx, E_cutoff=10**(-error), max_iter=100):

    def f(x):
        Schur = Schur_complement(x)
        sub_eigvals = jnp.linalg.eigvalsh(Schur)
        return sub_eigvals[subspace_eigvals_idx]

    xn = x0[subspace_eigvals_idx]
    fn = f(x0[subspace_eigvals_idx])

    # Iterative binary search
    for iteration in range(max_iter):
        # Update bounds based on fn's sign
        if fn < 0:
            upper_bound = xn
            lower_bound = fn + xn
        else:
            upper_bound = fn + xn
            lower_bound = xn

        # Update midpoint
        xn = (lower_bound + upper_bound) / 2

        # Update the function value at xn
        fn = f(xn)

        # Check for convergence
        if jnp.abs(fn) < E_cutoff:
            print(f"Converged in {iteration} iterations.")
            print(xn)
            return xn.item()

    print("Binary search did not converge within the maximum number of iterations.")
    print(xn)
    return xn.item()


for i, UU in enumerate(U_sweep):
    # Skip the first iteration
    if i == 0:
        continue
    print('solve:', i)
    
    # Construct the Hamiltonian for the coulomb = U
    H = reduced_hubbard_model(U=float(UU), indices=reduced_H_indices)
    
    # Use binary search to solve the eigenvalues of different band
    solved_eigval = []
    for subspace_eigvals_idx in range(k):
        subspace_solved_eigval = binary_search_solver(Schur_complement=lambda x: Schur_complement_qsp(H=H, E=x, init_eigvecs=H0_eigvecs_updated, degeneracy_idx=degeneracy_idx, dim=reduced_dim, poly=poly, kappa=kappa), 
                                                x0=solved_eigvals[-1], subspace_eigvals_idx=subspace_eigvals_idx)
        solved_eigval.append(subspace_solved_eigval)
    solved_eigvals.append(solved_eigval)
solved_eigvals = jnp.array(solved_eigvals).T
# Out:
# solve: 1
# Converged in 6 iterations.
# -11.135143044528167
# Converged in 6 iterations.
# -11.134932376931712
# Converged in 6 iterations.
# -11.134932376931697
# Converged in 6 iterations.
# -11.134932376931694
# Converged in 6 iterations.
# -11.134932376931676
# Converged in 6 iterations.
# -11.134875448136118
# Converged in 6 iterations.
# -11.134875448136107
# solve: 2
# Converged in 5 iterations.
# -11.072757579008687
# Converged in 5 iterations.
# -11.071972162186695
# Converged in 5 iterations.
# -11.07197216218668
# Converged in 5 iterations.
# -11.071972162186677
# Converged in 5 iterations.
# -11.071972162186661
# Converged in 5 iterations.
# -11.071749523518264
# Converged in 5 iterations.
# -11.071749523518253
# solve: 3
# Converged in 5 iterations.
# -11.012234698001443
# Converged in 5 iterations.
# -11.01057423711447
# Converged in 5 iterations.
# -11.010574237114454
# Converged in 5 iterations.
# -11.01057423711445
# Converged in 5 iterations.
# -11.010574237114435
# Converged in 5 iterations.
# -11.010081320138138
# Converged in 5 iterations.
# -11.01008132013813
# solve: 4
# Converged in 5 iterations.
# -10.953954855906943
# Converged in 5 iterations.
# -10.951182493370009
# Converged in 5 iterations.
# -10.951182493369995
# Converged in 5 iterations.
# -10.951182493369991
# Converged in 5 iterations.
# -10.951182493369974
# Converged in 5 iterations.
# -10.950322172013038
# Converged in 5 iterations.
# -10.950322172013031
# solve: 5
# Converged in 5 iterations.
# -10.897811834879597
# Converged in 5 iterations.
# -10.893743679475204
# Converged in 5 iterations.
# -10.89374367947519
# Converged in 5 iterations.
# -10.893743679475184
# Converged in 5 iterations.
# -10.89374367947517
# Converged in 5 iterations.
# -10.892426128346358
# Converged in 5 iterations.
# -10.89242612834635
# solve: 6
# Converged in 5 iterations.
# -10.84369884518402
# Converged in 5 iterations.
# -10.838196601201066
# Converged in 5 iterations.
# -10.838196601201052
# Converged in 5 iterations.
# -10.838196601201048
# Converged in 5 iterations.
# -10.83819660120103
# Converged in 5 iterations.
# -10.836339435489425
# Converged in 5 iterations.
# -10.836339435489418
# solve: 7
# Converged in 5 iterations.
# -10.791515147859576
# Converged in 5 iterations.
# -10.784480033672109
# Converged in 5 iterations.
# -10.784480033672093
# Converged in 5 iterations.
# -10.78448003367209
# Converged in 5 iterations.
# -10.784480033672073
# Converged in 5 iterations.
# -10.782008332708397
# Converged in 5 iterations.
# -10.78200833270839
# solve: 8
# Converged in 5 iterations.
# -10.741165473272876
# Converged in 5 iterations.
# -10.732533100191048
# Converged in 5 iterations.
# -10.732533100191034
# Converged in 5 iterations.
# -10.73253310019103
# Converged in 5 iterations.
# -10.732533100191013
# Converged in 5 iterations.
# -10.729379322596078
# Converged in 5 iterations.
# -10.729379322596069
# solve: 9
# Converged in 5 iterations.
# -10.692559546622613
# Converged in 5 iterations.
# -10.682295501207875
# Converged in 5 iterations.
# -10.68229550120786
# Converged in 5 iterations.
# -10.682295501207857
# Converged in 5 iterations.
# -10.682295501207841
# Converged in 5 iterations.
# -10.678399308504686
# Converged in 5 iterations.
# -10.678399308504678
# solve: 10
# Converged in 5 iterations.
# -10.645611779517907
# Converged in 5 iterations.
# -10.633707710535585
# Converged in 5 iterations.
# -10.63370771053557
# Converged in 5 iterations.
# -10.633707710535568
# Converged in 5 iterations.
# -10.633707710535552
# Converged in 5 iterations.
# -10.629015716207173
# Converged in 5 iterations.
# -10.629015716207164

# %%
for band in range(degeneracy_idx[0], degeneracy_idx[1] + 1):
    plt.plot(U_sweep_ED, H_eigvals_sweep[band], 'red')
for band in range(degeneracy_idx[0], degeneracy_idx[1] + 1):
    plt.plot(U_sweep, solved_eigvals[band], 'black', linestyle='dashed')

plt.plot(U_sweep_ED[0], H_eigvals_sweep[band][0], 'red', label='ED')
plt.plot(U_sweep[0], solved_eigvals[0, 0], 'black', linestyle='dashed', label='Binary')

plt.xlabel('U')
plt.ylabel('E')
plt.title(f'Eigenvalues vs U, {x_dimension}x{y_dimension}')
# plt.ylim(jnp.min(solved_eigvals) - 0.5, jnp.max(solved_eigvals) + 0.5)

plt.legend()
plt.show()

# %%
for i in range(7):
    print(solved_eigvals.T[-1, i]-H_eigvals_sweep.T[-1, i])
# Out:
# -0.0008644729402540463
# -0.0004092350662059374
# -0.0004092350661899502
# -0.00040923506618817385
# -0.000409235066173963
# -0.0008375854038416009
# -0.0008375854038344954

# %% [markdown]
# ## error $ = 10^{-6}$

# %%
kappa = 80
error = 6
file_name = f'coef_kappa{kappa}_error1e-{error}*'
file = glob.glob(file_name)
pcoefs = loadmat(file[0])
pcoefs = pcoefs['coef_full']

pcoefs = jnp.array([coef[0] for coef in pcoefs])
poly = Chebyshev(pcoefs)

# %%
U_sweep = jnp.linspace(0, U, 11)

# %%
solved_eigvals = [[vals.item() for vals in H0_eigvals_updated]]

def binary_search_solver(Schur_complement, x0, subspace_eigvals_idx, E_cutoff=10**(-error), max_iter=100):

    def f(x):
        Schur = Schur_complement(x)
        sub_eigvals = jnp.linalg.eigvalsh(Schur)
        return sub_eigvals[subspace_eigvals_idx]

    xn = x0[subspace_eigvals_idx]
    fn = f(x0[subspace_eigvals_idx])

    # Iterative binary search
    for iteration in range(max_iter):
        # Update bounds based on fn's sign
        if fn < 0:
            upper_bound = xn
            lower_bound = fn + xn
        else:
            upper_bound = fn + xn
            lower_bound = xn

        # Update midpoint
        xn = (lower_bound + upper_bound) / 2

        # Update the function value at xn
        fn = f(xn)

        # Check for convergence
        if jnp.abs(fn) < E_cutoff:
            print(f"Converged in {iteration} iterations.")
            print(xn)
            return xn.item()

    print("Binary search did not converge within the maximum number of iterations.")
    print(xn)
    return xn.item()


for i, UU in enumerate(U_sweep):
    # Skip the first iteration
    if i == 0:
        continue
    print('solve:', i)
    
    # Construct the Hamiltonian for the coulomb = U
    H = reduced_hubbard_model(U=float(UU), indices=reduced_H_indices)
    
    # Use binary search to solve the eigenvalues of different band
    solved_eigval = []
    for subspace_eigvals_idx in range(k):
        subspace_solved_eigval = binary_search_solver(Schur_complement=lambda x: Schur_complement_qsp(H=H, E=x, init_eigvecs=H0_eigvecs_updated, degeneracy_idx=degeneracy_idx, dim=reduced_dim, poly=poly, kappa=kappa), 
                                                x0=solved_eigvals[-1], subspace_eigvals_idx=subspace_eigvals_idx)
        solved_eigval.append(subspace_solved_eigval)
    solved_eigvals.append(solved_eigval)
solved_eigvals = jnp.array(solved_eigvals).T
# Out:
# solve: 1
# Converged in 15 iterations.
# -11.134634164389887
# Converged in 15 iterations.
# -11.134425042175273
# Converged in 15 iterations.
# -11.134425042175257
# Converged in 15 iterations.
# -11.134425042175252
# Converged in 15 iterations.
# -11.134425042175238
# Converged in 15 iterations.
# -11.134363640640007
# Converged in 15 iterations.
# -11.134363640639997
# solve: 2
# Converged in 15 iterations.
# -11.071772525987672
# Converged in 15 iterations.
# -11.07099058821996
# Converged in 15 iterations.
# -11.070990588219946
# Converged in 15 iterations.
# -11.070990588219942
# Converged in 15 iterations.
# -11.070990588219926
# Converged in 15 iterations.
# -11.070749557013563
# Converged in 15 iterations.
# -11.070749557013556
# solve: 3
# Converged in 15 iterations.
# -11.011281987560707
# Converged in 15 iterations.
# -11.009637068298169
# Converged in 15 iterations.
# -11.009637068298154
# Converged in 15 iterations.
# -11.00963706829815
# Converged in 15 iterations.
# -11.009637068298133
# Converged in 15 iterations.
# -11.009105196761332
# Converged in 15 iterations.
# -11.009105196761325
# solve: 4
# Converged in 15 iterations.
# -10.953037752787834
# Converged in 15 iterations.
# -10.950303128702771
# Converged in 15 iterations.
# -10.950303128702757
# Converged in 15 iterations.
# -10.950303128702753
# Converged in 15 iterations.
# -10.950303128702732
# Converged in 15 iterations.
# -10.949376357071117
# Converged in 15 iterations.
# -10.949376357071111
# solve: 5
# Converged in 15 iterations.
# -10.896923571754337
# Converged in 15 iterations.
# -10.892927012825512
# Converged in 15 iterations.
# -10.8929270128255
# Converged in 15 iterations.
# -10.892927012825492
# Converged in 15 iterations.
# -10.892927012825478
# Converged in 15 iterations.
# -10.891508481136851
# Converged in 15 iterations.
# -10.891508481136842
# solve: 6
# Converged in 15 iterations.
# -10.842831021202503
# Converged in 15 iterations.
# -10.837446877704881
# Converged in 15 iterations.
# -10.837446877704867
# Converged in 15 iterations.
# -10.837446877704863
# Converged in 15 iterations.
# -10.837446877704847
# Converged in 15 iterations.
# -10.83544690139408
# Converged in 15 iterations.
# -10.835446901394073
# solve: 7
# Converged in 15 iterations.
# -10.790658852612625
# Converged in 15 iterations.
# -10.783801079721126
# Converged in 15 iterations.
# -10.783801079721112
# Converged in 15 iterations.
# -10.783801079721108
# Converged in 15 iterations.
# -10.78380107972109
# Converged in 15 iterations.
# -10.781137061978683
# Converged in 15 iterations.
# -10.781137061978676
# solve: 8
# Converged in 15 iterations.
# -10.740312402141981
# Converged in 15 iterations.
# -10.731928429565976
# Converged in 15 iterations.
# -10.731928429565961
# Converged in 15 iterations.
# -10.731928429565958
# Converged in 15 iterations.
# -10.73192842956594
# Converged in 15 iterations.
# -10.728524720178346
# Converged in 15 iterations.
# -10.728524720178338
# solve: 9
# Converged in 15 iterations.
# -10.691703056235163
# Converged in 15 iterations.
# -10.681768417126037
# Converged in 15 iterations.
# -10.681768417126023
# Converged in 15 iterations.
# -10.681768417126019
# Converged in 15 iterations.
# -10.681768417126003
# Converged in 15 iterations.
# -10.67755612700213
# Converged in 15 iterations.
# -10.677556127002124
# solve: 10
# Converged in 15 iterations.
# -10.644747767207509
# Converged in 15 iterations.
# -10.633261407343142
# Converged in 15 iterations.
# -10.633261407343126
# Converged in 15 iterations.
# -10.633261407343124
# Converged in 15 iterations.
# -10.633261407343106
# Converged in 15 iterations.
# -10.628178187299723
# Converged in 15 iterations.
# -10.628178187299714

# %%
for band in range(degeneracy_idx[0], degeneracy_idx[1] + 1):
    plt.plot(U_sweep_ED, H_eigvals_sweep[band], 'red')
for band in range(degeneracy_idx[0], degeneracy_idx[1] + 1):
    plt.plot(U_sweep, solved_eigvals[band], 'black', linestyle='dashed')

plt.plot(U_sweep_ED[0], H_eigvals_sweep[band][0], 'red', label='ED')
plt.plot(U_sweep[0], solved_eigvals[0, 0], 'black', linestyle='dashed', label='Binary')

plt.xlabel('U')
plt.ylabel('E')
plt.title(f'Eigenvalues vs U, {x_dimension}x{y_dimension}')
# plt.ylim(jnp.min(solved_eigvals) - 0.5, jnp.max(solved_eigvals) + 0.5)

plt.legend()
plt.show()

# %%
for i in range(7):
    print(solved_eigvals.T[-1, i]-H_eigvals_sweep.T[-1, i])
# Out:
# -4.6062985603612105e-07
# 3.706812623782696e-05
# 3.706812625381417e-05
# 3.706812625559053e-05
# 3.706812627157774e-05
# -5.649639156501962e-08
# -5.6496384459592264e-08

# %% [markdown]
# ## error $ = 10^{-8}$

# %%
kappa = 80
error = 8
file_name = f'coef_kappa{kappa}_error1e-{error}*'
file = glob.glob(file_name)
pcoefs = loadmat(file[0])
pcoefs = pcoefs['coef_full']

pcoefs = jnp.array([coef[0] for coef in pcoefs])
poly = Chebyshev(pcoefs)

# %%
U_sweep = jnp.linspace(0, U, 11)

# %%
solved_eigvals = [[vals.item() for vals in H0_eigvals_updated]]

def binary_search_solver(Schur_complement, x0, subspace_eigvals_idx, E_cutoff=10**(-error), max_iter=100):

    def f(x):
        Schur = Schur_complement(x)
        sub_eigvals = jnp.linalg.eigvalsh(Schur)
        return sub_eigvals[subspace_eigvals_idx]

    xn = x0[subspace_eigvals_idx]
    fn = f(x0[subspace_eigvals_idx])

    # Iterative binary search
    for iteration in range(max_iter):
        # Update bounds based on fn's sign
        if fn < 0:
            upper_bound = xn
            lower_bound = fn + xn
        else:
            upper_bound = fn + xn
            lower_bound = xn

        # Update midpoint
        xn = (lower_bound + upper_bound) / 2

        # Update the function value at xn
        fn = f(xn)

        # Check for convergence
        if jnp.abs(fn) < E_cutoff:
            print(f"Converged in {iteration} iterations.")
            print(xn)
            return xn.item()

    print("Binary search did not converge within the maximum number of iterations.")
    print(xn)
    return xn.item()


for i, UU in enumerate(U_sweep):
    # Skip the first iteration
    if i == 0:
        continue
    print('solve:', i)
    
    # Construct the Hamiltonian for the coulomb = U
    H = reduced_hubbard_model(U=float(UU), indices=reduced_H_indices)
    
    # Use binary search to solve the eigenvalues of different band
    solved_eigval = []
    for subspace_eigvals_idx in range(k):
        subspace_solved_eigval = binary_search_solver(Schur_complement=lambda x: Schur_complement_qsp(H=H, E=x, init_eigvecs=H0_eigvecs_updated, degeneracy_idx=degeneracy_idx, dim=reduced_dim, poly=poly, kappa=kappa), 
                                                x0=solved_eigvals[-1], subspace_eigvals_idx=subspace_eigvals_idx)
        solved_eigval.append(subspace_solved_eigval)
    solved_eigvals.append(solved_eigval)
solved_eigvals = jnp.array(solved_eigvals).T
# Out:
# solve: 1
# Converged in 22 iterations.
# -11.134633180297701
# Converged in 22 iterations.
# -11.134424023642552
# Converged in 22 iterations.
# -11.134424023642538
# Converged in 22 iterations.
# -11.134424023642532
# Converged in 22 iterations.
# -11.134424023642516
# Converged in 22 iterations.
# -11.134362650841705
# Converged in 22 iterations.
# -11.134362650841695
# solve: 2
# Converged in 22 iterations.
# -11.071771597378678
# Converged in 22 iterations.
# -11.07098942693045
# Converged in 22 iterations.
# -11.070989426930435
# Converged in 22 iterations.
# -11.070989426930431
# Converged in 22 iterations.
# -11.070989426930414
# Converged in 22 iterations.
# -11.070748608445708
# Converged in 22 iterations.
# -11.070748608445701
# solve: 3
# Converged in 22 iterations.
# -11.011281122746563
# Converged in 22 iterations.
# -11.009635357604036
# Converged in 22 iterations.
# -11.00963535760402
# Converged in 22 iterations.
# -11.009635357604019
# Converged in 22 iterations.
# -11.009635357604001
# Converged in 22 iterations.
# -11.00910429127715
# Converged in 22 iterations.
# -11.009104291277144
# solve: 4
# Converged in 22 iterations.
# -10.953036956280759
# Converged in 22 iterations.
# -10.950300094410252
# Converged in 22 iterations.
# -10.950300094410238
# Converged in 22 iterations.
# -10.950300094410235
# Converged in 22 iterations.
# -10.950300094410217
# Converged in 22 iterations.
# -10.949375489641856
# Converged in 22 iterations.
# -10.949375489641852
# solve: 5
# Converged in 22 iterations.
# -10.896922844378643
# Converged in 22 iterations.
# -10.892921439004674
# Converged in 22 iterations.
# -10.89292143900466
# Converged in 22 iterations.
# -10.892921439004656
# Converged in 22 iterations.
# -10.892921439004638
# Converged in 22 iterations.
# -10.891507637317359
# Converged in 22 iterations.
# -10.89150763731735
# solve: 6
# Converged in 22 iterations.
# -10.84283036118662
# Converged in 22 iterations.
# -10.837437061756935
# Converged in 22 iterations.
# -10.83743706175692
# Converged in 22 iterations.
# -10.837437061756917
# Converged in 22 iterations.
# -10.8374370617569
# Converged in 22 iterations.
# -10.83544605498962
# Converged in 22 iterations.
# -10.835446054989612
# solve: 7
# Converged in 22 iterations.
# -10.790658256274522
# Converged in 22 iterations.
# -10.783784809272044
# Converged in 22 iterations.
# -10.783784809272028
# Converged in 22 iterations.
# -10.783784809272024
# Converged in 22 iterations.
# -10.783784809272007
# Converged in 22 iterations.
# -10.78113617288236
# Converged in 22 iterations.
# -10.78113617288235
# solve: 8
# Converged in 22 iterations.
# -10.740311863503287
# Converged in 22 iterations.
# -10.731902974308174
# Converged in 22 iterations.
# -10.73190297430816
# Converged in 22 iterations.
# -10.731902974308156
# Converged in 22 iterations.
# -10.731902974308138
# Converged in 22 iterations.
# -10.72852373231158
# Converged in 22 iterations.
# -10.72852373231157
# solve: 9
# Converged in 21 iterations.
# -10.691702570462809
# Converged in 21 iterations.
# -10.681730534343558
# Converged in 21 iterations.
# -10.681730534343544
# Converged in 21 iterations.
# -10.68173053434354
# Converged in 21 iterations.
# -10.681730534343524
# Converged in 22 iterations.
# -10.677554966267945
# Converged in 22 iterations.
# -10.677554966267937
# solve: 10
# Converged in 21 iterations.
# -10.644747314761155
# Converged in 21 iterations.
# -10.633207331409771
# Converged in 21 iterations.
# -10.633207331409757
# Converged in 21 iterations.
# -10.633207331409753
# Converged in 21 iterations.
# -10.633207331409738
# Converged in 21 iterations.
# -10.628176764149304
# Converged in 21 iterations.
# -10.628176764149295

# %%
for band in range(degeneracy_idx[0], degeneracy_idx[1] + 1):
    plt.plot(U_sweep_ED, H_eigvals_sweep[band], 'red')
for band in range(degeneracy_idx[0], degeneracy_idx[1] + 1):
    plt.plot(U_sweep, solved_eigvals[band], 'black', linestyle='dashed')

plt.plot(U_sweep_ED[0], H_eigvals_sweep[band][0], 'red', label='ED')
plt.plot(U_sweep[0], solved_eigvals[0, 0], 'black', linestyle='dashed', label='Binary')

plt.xlabel('U')
plt.ylabel('E')
plt.title(f'Eigenvalues vs U, {x_dimension}x{y_dimension}')
# plt.ylim(jnp.min(solved_eigvals) - 0.5, jnp.max(solved_eigvals) + 0.5)

plt.legend()
plt.show()

# %%
for i in range(7):
    print(solved_eigvals.T[-1, i]-H_eigvals_sweep.T[-1, i])
# Out:
# -8.183501876146693e-09
# 9.11440596080837e-05
# 9.114405962229455e-05
# 9.114405962584726e-05
# 9.114405964005812e-05
# 1.3666540272794236e-06
# 1.366654034384851e-06

# %% [markdown]
# ## $\Delta U = 2$

# %% [markdown]
# ## error $ = 10^{-3}$

# %%
kappa = 80
error = 3
file_name = f'coef_kappa{kappa}_error1e-{error}*'
file = glob.glob(file_name)
pcoefs = loadmat(file[0])
pcoefs = pcoefs['coef_full']

pcoefs = jnp.array([coef[0] for coef in pcoefs])
poly = Chebyshev(pcoefs)

# %%
U_sweep = jnp.linspace(0, U, 2)

# %%
solved_eigvals = [[vals.item() for vals in H0_eigvals_updated]]

def binary_search_solver(Schur_complement, x0, subspace_eigvals_idx, E_cutoff=10**(-error), max_iter=100):

    def f(x):
        Schur = Schur_complement(x)
        sub_eigvals = jnp.linalg.eigvalsh(Schur)
        return sub_eigvals[subspace_eigvals_idx]

    xn = x0[subspace_eigvals_idx]
    fn = f(x0[subspace_eigvals_idx])

    # Iterative binary search
    for iteration in range(max_iter):
        # Update bounds based on fn's sign
        if fn < 0:
            upper_bound = xn
            lower_bound = fn + xn
        else:
            upper_bound = fn + xn
            lower_bound = xn

        # Update midpoint
        xn = (lower_bound + upper_bound) / 2

        # Update the function value at xn
        fn = f(xn)

        # Check for convergence
        if jnp.abs(fn) < E_cutoff:
            print(f"Converged in {iteration} iterations.")
            print(xn)
            return xn.item()

    print("Binary search did not converge within the maximum number of iterations.")
    print(xn)
    return xn.item()


for i, UU in enumerate(U_sweep):
    # Skip the first iteration
    if i == 0:
        continue
    print('solve:', i)
    
    # Construct the Hamiltonian for the coulomb = U
    H = reduced_hubbard_model(U=float(UU), indices=reduced_H_indices)
    
    # Use binary search to solve the eigenvalues of different band
    solved_eigval = []
    for subspace_eigvals_idx in range(k):
        subspace_solved_eigval = binary_search_solver(Schur_complement=lambda x: Schur_complement_qsp(H=H, E=x, init_eigvecs=H0_eigvecs_updated, degeneracy_idx=degeneracy_idx, dim=reduced_dim, poly=poly, kappa=kappa), 
                                                x0=solved_eigvals[-1], subspace_eigvals_idx=subspace_eigvals_idx)
        solved_eigval.append(subspace_solved_eigval)
    solved_eigvals.append(solved_eigval)
solved_eigvals = jnp.array(solved_eigvals).T
# Out:
# solve: 1
# Converged in 8 iterations.
# -10.645893977114415
# Converged in 9 iterations.
# -10.633482679549203
# Converged in 9 iterations.
# -10.63348267954919
# Converged in 9 iterations.
# -10.633482679549186
# Converged in 9 iterations.
# -10.633482679549171
# Converged in 9 iterations.
# -10.628783581200201
# Converged in 9 iterations.
# -10.628783581200194

# %%
for band in range(degeneracy_idx[0], degeneracy_idx[1] + 1):
    plt.plot(U_sweep_ED, H_eigvals_sweep[band], 'red')
for band in range(degeneracy_idx[0], degeneracy_idx[1] + 1):
    plt.plot(U_sweep, solved_eigvals[band], 'black', linestyle='dashed')

plt.plot(U_sweep_ED[0], H_eigvals_sweep[band][0], 'red', label='ED')
plt.plot(U_sweep[0], solved_eigvals[0, 0], 'black', linestyle='dashed', label='Binary')

plt.xlabel('U')
plt.ylabel('E')
plt.title(f'Eigenvalues vs U, {x_dimension}x{y_dimension}')
# plt.ylim(jnp.min(solved_eigvals) - 0.5, jnp.max(solved_eigvals) + 0.5)

plt.legend()
plt.show()

# %%
for i in range(7):
    print(solved_eigvals.T[-1, i]-H_eigvals_sweep.T[-1, i])
# Out:
# -0.0011466705367624286
# -0.0001842040798241129
# -0.00018420407980990205
# -0.00018420407980634934
# -0.00018420407979391484
# -0.0006054503968702107
# -0.0006054503968648817

# %% [markdown]
# # Wegstien's method
# ### ($\Delta U = 0.2$)

# %% [markdown]
# ## error $ = 10^{-3}$

# %%
kappa = 80
error = 3
file_name = f'coef_kappa{kappa}_error1e-{error}*'
file = glob.glob(file_name)
pcoefs = loadmat(file[0])
pcoefs = pcoefs['coef_full']

pcoefs = jnp.array([coef[0] for coef in pcoefs])
poly = Chebyshev(pcoefs)

# %%
U_sweep = jnp.linspace(0, U, 11)

# %%
solved_eigvals = [[vals.item() for vals in H0_eigvals_updated]]

def Wegstein_solver(Schur_complement, x0, subspace_eigvals_idx, E_cutoff=10**(-error), max_iter=100):

    def f(x):
        Schur = Schur_complement(x)
        sub_eigvals = jnp.linalg.eigvalsh(Schur)
        return sub_eigvals[subspace_eigvals_idx] + x
    
    # Initialize xn and fn
    xn = [x0[subspace_eigvals_idx], f(x0[subspace_eigvals_idx])]
    fn = [xn[1], f(xn[1])]    
    
    for i in range(1, max_iter):
        
        x_new = (xn[i-1]*fn[i] - xn[i]*fn[i-1]) / (xn[i-1] + fn[i] - xn[i] - fn[i-1])
        xn.append(x_new)
        fn.append(f(x_new))
        
        # If the energy difference is less than cutoff, the algorithm converge
        if abs(x_new - xn[i]) < E_cutoff:
            print(f"Converged in {i} iterations.")
            print(fn[-1])
            return fn[-1]
    
    print("Wegstein method did not converge within the maximum number of iterations.")
    print(fn[-1])   
    return fn[-1]


for i, UU in enumerate(U_sweep):
    # Skip the first iteration
    if i == 0:
        continue
    print('solve:', i)
    
    # Construct the Hamiltonian for the coulomb = U
    H = reduced_hubbard_model(U=float(UU), indices=reduced_H_indices)
    
    # Use binary search to solve the eigenvalues of different band
    solved_eigval = []
    for subspace_eigvals_idx in range(k):
        subspace_solved_eigval = Wegstein_solver(Schur_complement=lambda x: Schur_complement_qsp(H=H, E=x, init_eigvecs=H0_eigvecs_updated, degeneracy_idx=degeneracy_idx, dim=reduced_dim, poly=poly, kappa=kappa), 
                                                x0=solved_eigvals[-1], subspace_eigvals_idx=subspace_eigvals_idx)
        solved_eigval.append(subspace_solved_eigval)
    solved_eigvals.append(solved_eigval)
solved_eigvals = jnp.array(solved_eigvals).T
# Out:
# solve: 1
# Converged in 1 iterations.
# -11.134632948439034
# Converged in 1 iterations.
# -11.134420539088044
# Converged in 1 iterations.
# -11.13442053908803
# Converged in 1 iterations.
# -11.134420539088024
# Converged in 1 iterations.
# -11.134420539088008
# Converged in 1 iterations.
# -11.13436311389042
# Converged in 1 iterations.
# -11.13436311389041
# solve: 2
# Converged in 1 iterations.
# -11.0717711128668
# Converged in 1 iterations.
# -11.070976135026834
# Converged in 1 iterations.
# -11.07097613502682
# Converged in 1 iterations.
# -11.070976135026816
# Converged in 1 iterations.
# -11.0709761350268
# Converged in 1 iterations.
# -11.070750552176138
# Converged in 1 iterations.
# -11.070750552176131
# solve: 3
# Converged in 1 iterations.
# -11.011281930625827
# Converged in 1 iterations.
# -11.00960684775034
# Converged in 1 iterations.
# -11.009606847750325
# Converged in 1 iterations.
# -11.009606847750323
# Converged in 1 iterations.
# -11.009606847750305
# Converged in 1 iterations.
# -11.009108977909396
# Converged in 1 iterations.
# -11.009108977909388
# solve: 4
# Converged in 1 iterations.
# -10.95304278420159
# Converged in 1 iterations.
# -10.95025185002127
# Converged in 1 iterations.
# -10.950251850021255
# Converged in 1 iterations.
# -10.950251850021253
# Converged in 1 iterations.
# -10.950251850021234
# Converged in 1 iterations.
# -10.949384605369405
# Converged in 1 iterations.
# -10.949384605369401
# solve: 5
# Converged in 1 iterations.
# -10.896939484058066
# Converged in 1 iterations.
# -10.89284980000095
# Converged in 1 iterations.
# -10.892849800000937
# Converged in 1 iterations.
# -10.892849800000931
# Converged in 1 iterations.
# -10.892849800000917
# Converged in 1 iterations.
# -10.891523418844088
# Converged in 1 iterations.
# -10.891523418844077
# solve: 6
# Converged in 1 iterations.
# -10.842865009451117
# Converged in 1 iterations.
# -10.837339175235355
# Converged in 1 iterations.
# -10.837339175235341
# Converged in 1 iterations.
# -10.837339175235336
# Converged in 1 iterations.
# -10.837339175235318
# Converged in 1 iterations.
# -10.83547136584792
# Converged in 1 iterations.
# -10.835471365847914
# solve: 7
# Converged in 1 iterations.
# -10.790718536732818
# Converged in 1 iterations.
# -10.783658568781384
# Converged in 1 iterations.
# -10.783658568781366
# Converged in 1 iterations.
# -10.78365856878136
# Converged in 1 iterations.
# -10.783658568781345
# Converged in 1 iterations.
# -10.781174527831386
# Converged in 1 iterations.
# -10.781174527831379
# solve: 8
# Converged in 1 iterations.
# -10.740404736526338
# Converged in 1 iterations.
# -10.731746949115456
# Converged in 1 iterations.
# -10.731746949115445
# Converged in 1 iterations.
# -10.73174694911544
# Converged in 1 iterations.
# -10.731746949115422
# Converged in 1 iterations.
# -10.728579271419385
# Converged in 1 iterations.
# -10.728579271419376
# solve: 9
# Converged in 1 iterations.
# -10.691833294712204
# Converged in 1 iterations.
# -10.681543886101233
# Converged in 1 iterations.
# -10.681543886101212
# Converged in 1 iterations.
# -10.681543886101213
# Converged in 1 iterations.
# -10.681543886101197
# Converged in 1 iterations.
# -10.67763238301601
# Converged in 1 iterations.
# -10.677632383016
# solve: 10
# Converged in 1 iterations.
# -10.64491860175399
# Converged in 1 iterations.
# -10.632989745676571
# Converged in 1 iterations.
# -10.632989745676555
# Converged in 1 iterations.
# -10.632989745676547
# Converged in 1 iterations.
# -10.632989745676536
# Converged in 1 iterations.
# -10.628281189286424
# Converged in 1 iterations.
# -10.628281189286412

# %%
for band in range(degeneracy_idx[0], degeneracy_idx[1] + 1):
    plt.plot(U_sweep_ED, H_eigvals_sweep[band], 'red')
for band in range(degeneracy_idx[0], degeneracy_idx[1] + 1):
    plt.plot(U_sweep, solved_eigvals[band], 'black', linestyle='dashed')

plt.plot(U_sweep_ED[0], H_eigvals_sweep[band][0], 'red', label='ED')
plt.plot(U_sweep[0], solved_eigvals[0, 0], 'black', linestyle='dashed', label='Wegstein')

plt.xlabel('U')
plt.ylabel('E')
plt.title(f'Eigenvalues vs U, {x_dimension}x{y_dimension}')
# plt.ylim(jnp.min(solved_eigvals) - 0.5, jnp.max(solved_eigvals) + 0.5)

plt.legend()
plt.show()

# %%
for i in range(7):
    print(solved_eigvals.T[-1, i]-H_eigvals_sweep.T[-1, i])
# Out:
# -0.00017129517633662772
# 0.000308729792807938
# 0.0003087297928239252
# 0.000308729792832807
# 0.0003087297928416888
# -0.0001030584830932213
# -0.00010305848308256316

# %% [markdown]
# ## error $ = 10^{-6}$

# %%
kappa = 80
error = 6
file_name = f'coef_kappa{kappa}_error1e-{error}*'
file = glob.glob(file_name)
pcoefs = loadmat(file[0])
pcoefs = pcoefs['coef_full']

pcoefs = jnp.array([coef[0] for coef in pcoefs])
poly = Chebyshev(pcoefs)

# %%
U_sweep = jnp.linspace(0, U, 11)

# %%
solved_eigvals = [[vals.item() for vals in H0_eigvals_updated]]

def Wegstein_solver(Schur_complement, x0, subspace_eigvals_idx, E_cutoff=10**(-error), max_iter=100):

    def f(x):
        Schur = Schur_complement(x)
        sub_eigvals = jnp.linalg.eigvalsh(Schur)
        return sub_eigvals[subspace_eigvals_idx] + x
    
    # Initialize xn and fn
    xn = [x0[subspace_eigvals_idx], f(x0[subspace_eigvals_idx])]
    fn = [xn[1], f(xn[1])]    
    
    for i in range(1, max_iter):
        
        x_new = (xn[i-1]*fn[i] - xn[i]*fn[i-1]) / (xn[i-1] + fn[i] - xn[i] - fn[i-1])
        xn.append(x_new)
        fn.append(f(x_new))
        
        # If the energy difference is less than cutoff, the algorithm converge
        if abs(x_new - xn[i]) < E_cutoff:
            print(f"Converged in {i} iterations.")
            print(fn[-1])
            return fn[-1]
    
    print("Wegstein method did not converge within the maximum number of iterations.")
    print(fn[-1])   
    return fn[-1]


for i, UU in enumerate(U_sweep):
    # Skip the first iteration
    if i == 0:
        continue
    print('solve:', i)
    
    # Construct the Hamiltonian for the coulomb = U
    H = reduced_hubbard_model(U=float(UU), indices=reduced_H_indices)
    
    # Use binary search to solve the eigenvalues of different band
    solved_eigval = []
    for subspace_eigvals_idx in range(k):
        subspace_solved_eigval = Wegstein_solver(Schur_complement=lambda x: Schur_complement_qsp(H=H, E=x, init_eigvecs=H0_eigvecs_updated, degeneracy_idx=degeneracy_idx, dim=reduced_dim, poly=poly, kappa=kappa), 
                                                x0=solved_eigvals[-1], subspace_eigvals_idx=subspace_eigvals_idx)
        solved_eigval.append(subspace_solved_eigval)
    solved_eigvals.append(solved_eigval)
solved_eigvals = jnp.array(solved_eigvals).T
# Out:
# solve: 1
# Converged in 2 iterations.
# -11.13463316957137
# Converged in 2 iterations.
# -11.134424043920793
# Converged in 2 iterations.
# -11.134424043920925
# Converged in 2 iterations.
# -11.134424043920783
# Converged in 2 iterations.
# -11.13442404392017
# Converged in 2 iterations.
# -11.13436264111123
# Converged in 2 iterations.
# -11.134362641111329
# solve: 2
# Converged in 2 iterations.
# -11.071771576366025
# Converged in 2 iterations.
# -11.070989629182632
# Converged in 2 iterations.
# -11.070989629182804
# Converged in 2 iterations.
# -11.07098962918278
# Converged in 2 iterations.
# -11.070989629182385
# Converged in 2 iterations.
# -11.070748593988002
# Converged in 2 iterations.
# -11.07074859398796
# solve: 3
# Converged in 2 iterations.
# -11.011281084403075
# Converged in 2 iterations.
# -11.009636151019427
# Converged in 2 iterations.
# -11.009636151018908
# Converged in 2 iterations.
# -11.009636151019382
# Converged in 2 iterations.
# -11.009636151019503
# Converged in 2 iterations.
# -11.009104272460231
# Converged in 2 iterations.
# -11.009104272460426
# solve: 4
# Converged in 2 iterations.
# -10.953036896568465
# Converged in 2 iterations.
# -10.95030225498085
# Converged in 2 iterations.
# -10.9503022549806
# Converged in 2 iterations.
# -10.950302254980906
# Converged in 2 iterations.
# -10.950302254980869
# Converged in 2 iterations.
# -10.949375473114038
# Converged in 2 iterations.
# -10.949375473113985
# solve: 5
# Converged in 2 iterations.
# -10.896922762311718
# Converged in 2 iterations.
# -10.892926183786313
# Converged in 2 iterations.
# -10.892926183785878
# Converged in 2 iterations.
# -10.892926183785931
# Converged in 2 iterations.
# -10.892926183785846
# Converged in 2 iterations.
# -10.891507638597009
# Converged in 2 iterations.
# -10.891507638597416
# solve: 6
# Converged in 2 iterations.
# -10.84283025786275
# Converged in 2 iterations.
# -10.837446093863448
# Converged in 2 iterations.
# -10.837446093863406
# Converged in 2 iterations.
# -10.837446093863417
# Converged in 2 iterations.
# -10.837446093863086
# Converged in 2 iterations.
# -10.835446100846431
# Converged in 2 iterations.
# -10.835446100845953
# solve: 7
# Converged in 2 iterations.
# -10.790658134302012
# Converged in 2 iterations.
# -10.783800341054487
# Converged in 2 iterations.
# -10.783800341054343
# Converged in 2 iterations.
# -10.783800341055317
# Converged in 2 iterations.
# -10.783800341055164
# Converged in 2 iterations.
# -10.781136303549069
# Converged in 2 iterations.
# -10.781136303548228
# solve: 8
# Converged in 2 iterations.
# -10.740311727478874
# Converged in 2 iterations.
# -10.731927735584696
# Converged in 2 iterations.
# -10.731927735584355
# Converged in 2 iterations.
# -10.731927735584586
# Converged in 2 iterations.
# -10.73192773558481
# Converged in 2 iterations.
# -10.728524003597801
# Converged in 2 iterations.
# -10.728524003597148
# solve: 9
# Converged in 2 iterations.
# -10.691702423609314
# Converged in 2 iterations.
# -10.681767766944349
# Converged in 2 iterations.
# -10.681767766944368
# Converged in 2 iterations.
# -10.68176776694479
# Converged in 2 iterations.
# -10.681767766945084
# Converged in 2 iterations.
# -10.677555451661467
# Converged in 2 iterations.
# -10.67755545166108
# solve: 10
# Converged in 2 iterations.
# -10.64474717485071
# Converged in 2 iterations.
# -10.633260799752174
# Converged in 2 iterations.
# -10.633260799752394
# Converged in 2 iterations.
# -10.63326079975274
# Converged in 2 iterations.
# -10.633260799752136
# Converged in 2 iterations.
# -10.62817755230275
# Converged in 2 iterations.
# -10.628177552302875

# %%
for band in range(degeneracy_idx[0], degeneracy_idx[1] + 1):
    plt.plot(U_sweep_ED, H_eigvals_sweep[band], 'red')
for band in range(degeneracy_idx[0], degeneracy_idx[1] + 1):
    plt.plot(U_sweep, solved_eigvals[band], 'black', linestyle='dashed')

plt.plot(U_sweep_ED[0], H_eigvals_sweep[band][0], 'red', label='ED')
plt.plot(U_sweep[0], solved_eigvals[0, 0], 'black', linestyle='dashed', label='Wegstein')

plt.xlabel('U')
plt.ylabel('E')
plt.title(f'Eigenvalues vs U, {x_dimension}x{y_dimension}')
# plt.ylim(jnp.min(solved_eigvals) - 0.5, jnp.max(solved_eigvals) + 0.5)

plt.legend()
plt.show()

# %%
for i in range(7):
    print(solved_eigvals.T[-1, i]-H_eigvals_sweep.T[-1, i])
# Out:
# 1.31726942242949e-07
# 3.767571720558749e-05
# 3.767571698531924e-05
# 3.767571663892966e-05
# 3.7675717241114626e-05
# 5.785005807723564e-07
# 5.785004546510208e-07

# %% [markdown]
# ## error $ = 10^{-8}$

# %%
kappa = 80
error = 8
file_name = f'coef_kappa{kappa}_error1e-{error}*'
file = glob.glob(file_name)
pcoefs = loadmat(file[0])
pcoefs = pcoefs['coef_full']

pcoefs = jnp.array([coef[0] for coef in pcoefs])
poly = Chebyshev(pcoefs)

# %%
U_sweep = jnp.linspace(0, U, 11)

# %%
solved_eigvals = [[vals.item() for vals in H0_eigvals_updated]]

def Wegstein_solver(Schur_complement, x0, subspace_eigvals_idx, E_cutoff=10**(-error), max_iter=100):

    def f(x):
        Schur = Schur_complement(x)
        sub_eigvals = jnp.linalg.eigvalsh(Schur)
        return sub_eigvals[subspace_eigvals_idx] + x
    
    # Initialize xn and fn
    xn = [x0[subspace_eigvals_idx], f(x0[subspace_eigvals_idx])]
    fn = [xn[1], f(xn[1])]    
    
    for i in range(1, max_iter):
        
        x_new = (xn[i-1]*fn[i] - xn[i]*fn[i-1]) / (xn[i-1] + fn[i] - xn[i] - fn[i-1])
        xn.append(x_new)
        fn.append(f(x_new))
        
        # If the energy difference is less than cutoff, the algorithm converge
        if abs(x_new - xn[i]) < E_cutoff:
            print(f"Converged in {i} iterations.")
            print(fn[-1])
            return fn[-1]
    
    print("Wegstein method did not converge within the maximum number of iterations.")
    print(fn[-1])   
    return fn[-1]


for i, UU in enumerate(U_sweep):
    # Skip the first iteration
    if i == 0:
        continue
    print('solve:', i)
    
    # Construct the Hamiltonian for the coulomb = U
    H = reduced_hubbard_model(U=float(UU), indices=reduced_H_indices)
    
    # Use binary search to solve the eigenvalues of different band
    solved_eigval = []
    for subspace_eigvals_idx in range(k):
        subspace_solved_eigval = Wegstein_solver(Schur_complement=lambda x: Schur_complement_qsp(H=H, E=x, init_eigvecs=H0_eigvecs_updated, degeneracy_idx=degeneracy_idx, dim=reduced_dim, poly=poly, kappa=kappa), 
                                                x0=solved_eigvals[-1], subspace_eigvals_idx=subspace_eigvals_idx)
        solved_eigval.append(subspace_solved_eigval)
    solved_eigvals.append(solved_eigval)
solved_eigvals = jnp.array(solved_eigvals).T
# Out:
# solve: 1
# Converged in 2 iterations.
# -11.134633172534395
# Converged in 2 iterations.
# -11.134424015851376
# Converged in 2 iterations.
# -11.134424015851465
# Converged in 2 iterations.
# -11.134424015852014
# Converged in 2 iterations.
# -11.134424015851355
# Converged in 2 iterations.
# -11.13436264303994
# Converged in 2 iterations.
# -11.134362643039657
# solve: 2
# Converged in 2 iterations.
# -11.07177158999228
# Converged in 2 iterations.
# -11.070989419468427
# Converged in 2 iterations.
# -11.070989419468505
# Converged in 2 iterations.
# -11.070989419468312
# Converged in 2 iterations.
# -11.070989419467791
# Converged in 2 iterations.
# -11.070748600948486
# Converged in 2 iterations.
# -11.070748600948232
# solve: 3
# Converged in 2 iterations.
# -11.011281115758214
# Converged in 2 iterations.
# -11.009635350501373
# Converged in 2 iterations.
# -11.00963535050123
# Converged in 2 iterations.
# -11.00963535050111
# Converged in 2 iterations.
# -11.009635350500938
# Converged in 2 iterations.
# -11.009104284111775
# Converged in 2 iterations.
# -11.009104284111789
# solve: 4
# Converged in 2 iterations.
# -10.953036949699591
# Converged in 2 iterations.
# -10.95030008768886
# Converged in 2 iterations.
# -10.950300087688962
# Converged in 2 iterations.
# -10.950300087688639
# Converged in 2 iterations.
# -10.950300087689183
# Converged in 2 iterations.
# -10.949375482828303
# Converged in 2 iterations.
# -10.949375482827833
# solve: 5
# Converged in 2 iterations.
# -10.896922838208353
# Converged in 2 iterations.
# -10.892921432679223
# Converged in 2 iterations.
# -10.892921432679413
# Converged in 2 iterations.
# -10.892921432679447
# Converged in 2 iterations.
# -10.892921432679156
# Converged in 2 iterations.
# -10.891507630868997
# Converged in 2 iterations.
# -10.891507630868894
# solve: 6
# Converged in 2 iterations.
# -10.842830355423677
# Converged in 2 iterations.
# -10.837437055834004
# Converged in 2 iterations.
# -10.837437055833446
# Converged in 2 iterations.
# -10.837437055833597
# Converged in 2 iterations.
# -10.837437055833828
# Converged in 2 iterations.
# -10.835446048914635
# Converged in 2 iterations.
# -10.835446048914303
# solve: 7
# Converged in 51 iterations.
# -10.790658250762299
# Converged in 14 iterations.
# -10.783784803797275
# Converged in 9 iterations.
# -10.783784803763876
# Converged in 12 iterations.
# -10.783784803308068
# Converged in 34 iterations.
# -10.783784803786032
# Converged in 4 iterations.
# -10.781136166484657
# Converged in 41 iterations.
# -10.781136167579524
# solve: 8
# Converged in 8 iterations.
# -10.740311858364729
# Converged in 11 iterations.
# -10.731902969827514
# Converged in 7 iterations.
# -10.731902969213994
# Converged in 21 iterations.
# -10.73190296996309
# Converged in 12 iterations.
# -10.73190296920303
# Converged in 14 iterations.
# -10.728523726931726
# Converged in 38 iterations.
# -10.728523726750199
# solve: 9
# Converged in 23 iterations.
# -10.691702561146206
# Converged in 37 iterations.
# -10.681730524595315
# Converged in 5 iterations.
# -10.681730524797963
# Converged in 7 iterations.
# -10.681730524844838
# Converged in 12 iterations.
# -10.68173052560926
# Converged in 57 iterations.
# -10.677554961238082
# Converged in 22 iterations.
# -10.677554961846209
# solve: 10
# Converged in 10 iterations.
# -10.644747306618422
# Converged in 16 iterations.
# -10.63320732263492
# Converged in 5 iterations.
# -10.633207322206617
# Converged in 6 iterations.
# -10.633207322119526
# Converged in 6 iterations.
# -10.633207323043917
# Converged in 10 iterations.
# -10.628176755612515
# Converged in 5 iterations.
# -10.628176754660073

# %%
for band in range(degeneracy_idx[0], degeneracy_idx[1] + 1):
    plt.plot(U_sweep_ED, H_eigvals_sweep[band], 'red')
for band in range(degeneracy_idx[0], degeneracy_idx[1] + 1):
    plt.plot(U_sweep, solved_eigvals[band], 'black', linestyle='dashed')

plt.plot(U_sweep_ED[0], H_eigvals_sweep[band][0], 'red', label='ED')
plt.plot(U_sweep[0], solved_eigvals[0, 0], 'black', linestyle='dashed', label='Wegstein')

plt.xlabel('U')
plt.ylabel('E')
plt.title(f'Eigenvalues vs U, {x_dimension}x{y_dimension}')
# plt.ylim(jnp.min(solved_eigvals) - 0.5, jnp.max(solved_eigvals) + 0.5)

plt.legend()
plt.show()

# %%
for i in range(7):
    print(solved_eigvals.T[-1, i]-H_eigvals_sweep.T[-1, i])
# Out:
# -4.076916582107515e-11
# 9.115283445915168e-05
# 9.11532627618783e-05
# 9.115334985310142e-05
# 9.115242546009483e-05
# 1.3751908163328608e-06
# 1.376143256237583e-06

# %% [markdown]
# ## $\Delta U = 2$

# %% [markdown]
# ## error $ = 10^{-3}$

# %%
kappa = 80
error = 3
file_name = f'coef_kappa{kappa}_error1e-{error}*'
file = glob.glob(file_name)
pcoefs = loadmat(file[0])
pcoefs = pcoefs['coef_full']

pcoefs = jnp.array([coef[0] for coef in pcoefs])
poly = Chebyshev(pcoefs)

# %%
U_sweep = jnp.linspace(0, U, 2)

# %%
solved_eigvals = [[vals.item() for vals in H0_eigvals_updated]]

def Wegstein_solver(Schur_complement, x0, subspace_eigvals_idx, E_cutoff=10**(-error), max_iter=100):

    def f(x):
        Schur = Schur_complement(x)
        sub_eigvals = jnp.linalg.eigvalsh(Schur)
        return sub_eigvals[subspace_eigvals_idx] + x
    
    # Initialize xn and fn
    xn = [x0[subspace_eigvals_idx], f(x0[subspace_eigvals_idx])]
    fn = [xn[1], f(xn[1])]    
    
    for i in range(1, max_iter):
        
        x_new = (xn[i-1]*fn[i] - xn[i]*fn[i-1]) / (xn[i-1] + fn[i] - xn[i] - fn[i-1])
        xn.append(x_new)
        fn.append(f(x_new))
        
        # If the energy difference is less than cutoff, the algorithm converge
        if abs(x_new - xn[i]) < E_cutoff:
            print(f"Converged in {i} iterations.")
            print(fn[-1])
            return fn[-1]
    
    print("Wegstein method did not converge within the maximum number of iterations.")
    print(fn[-1])   
    return fn[-1]


for i, UU in enumerate(U_sweep):
    # Skip the first iteration
    if i == 0:
        continue
    print('solve:', i)
    
    # Construct the Hamiltonian for the coulomb = U
    H = reduced_hubbard_model(U=float(UU), indices=reduced_H_indices)
    
    # Use binary search to solve the eigenvalues of different band
    solved_eigval = []
    for subspace_eigvals_idx in range(k):
        subspace_solved_eigval = Wegstein_solver(Schur_complement=lambda x: Schur_complement_qsp(H=H, E=x, init_eigvecs=H0_eigvecs_updated, degeneracy_idx=degeneracy_idx, dim=reduced_dim, poly=poly, kappa=kappa), 
                                                x0=solved_eigvals[-1], subspace_eigvals_idx=subspace_eigvals_idx)
        solved_eigval.append(subspace_solved_eigval)
    solved_eigvals.append(solved_eigval)
solved_eigvals = jnp.array(solved_eigvals).T
# Out:
# solve: 1
# Converged in 2 iterations.
# -10.644918602143381
# Converged in 2 iterations.
# -10.632989746081206
# Converged in 2 iterations.
# -10.63298974608112
# Converged in 2 iterations.
# -10.632989746081156
# Converged in 2 iterations.
# -10.632989746081112
# Converged in 2 iterations.
# -10.628281189623793
# Converged in 2 iterations.
# -10.628281189623785

# %%
for band in range(degeneracy_idx[0], degeneracy_idx[1] + 1):
    plt.plot(U_sweep_ED, H_eigvals_sweep[band], 'red')
for band in range(degeneracy_idx[0], degeneracy_idx[1] + 1):
    plt.plot(U_sweep, solved_eigvals[band], 'black', linestyle='dashed')

plt.plot(U_sweep_ED[0], H_eigvals_sweep[band][0], 'red', label='ED')
plt.plot(U_sweep[0], solved_eigvals[0, 0], 'black', linestyle='dashed', label='Wegstein')

plt.xlabel('U')
plt.ylabel('E')
plt.title(f'Eigenvalues vs U, {x_dimension}x{y_dimension}')
# plt.ylim(jnp.min(solved_eigvals) - 0.5, jnp.max(solved_eigvals) + 0.5)

plt.legend()
plt.show()

# %%
for i in range(7):
    print(solved_eigvals.T[-1, i]-H_eigvals_sweep.T[-1, i])
# Out:
# -0.00017129556572825777
# 0.0003087293881733899
# 0.00030872938825865504
# 0.0003087293882231279
# 0.00030872938826576046
# -0.00010305882046246495
# -0.00010305882045535952
