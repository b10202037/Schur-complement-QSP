# %%
import matplotlib.pyplot as plt
import openfermion as of
from Hubbard_Model_nnn import *
import jax.numpy as jnp
from itertools import product
from jax import config
from numpy.polynomial.chebyshev import Chebyshev
from scipy.io import loadmat
import scipy.sparse as sp
import glob
config.update("jax_enable_x64", True)

# %% [markdown]
# # Set parameters.

# %%
# Parameters.
x_dimension = 3
y_dimension = 3
n_up = 2
n_down = 2

n_site = x_dimension * y_dimension

U = 4
t = 1.0
t_prime = 0.3
mu = 0.0

# %% [markdown]
# ## Construct the reduced Hamiltonian.

# %%
def reduced_hubbard_model(U, indices):
    hopping_terms = fermi_hubbard_nnn(x_dimension, y_dimension, tunneling=t, nnn_tunneling=t_prime, coulomb=U, chemical_potential=mu, periodic=True)
    hopping_terms = of.get_sparse_operator(hopping_terms)
    H_hubbard = hopping_terms[jnp.ix_(indices, indices)].toarray()

    return H_hubbard

# %%
valid_indices = []
for bits in product('01', repeat= 2 * x_dimension * y_dimension):

    spin_up_indices = bits[::2]
    spin_down_indices = bits[1::2]

    if spin_up_indices.count('1') == n_up and spin_down_indices.count('1') == n_down:
        binary_str = ''.join(bits)
        valid_indices.append(int(binary_str, 2))

reduced_H_indices = jnp.array(valid_indices)

H_reduced = reduced_hubbard_model(U=U, indices=reduced_H_indices)
reduced_dim = len(H_reduced)
print('reduced_dim =', reduced_dim)

H_reduced_eigvals, H_reduced_eigvecs = jnp.linalg.eigh(H_reduced)
print(f"Eigenvalues:", jnp.round(H_reduced_eigvals[:8], 3))
# Out:
# reduced_dim = 1296
# Eigenvalues: [-10.251 -10.227 -10.227 -10.227 -10.227 -10.211 -10.211 -10.054]

# %%
U_sweep_ED = jnp.linspace(0, U, 80)

H_eigvals_sweep = []

for UU in U_sweep_ED:
    H = reduced_hubbard_model(U=float(UU), indices=reduced_H_indices)
    eigvals = jnp.linalg.eigvalsh(H)
    H_eigvals_sweep.append(eigvals)

H_eigvals_sweep = jnp.array(H_eigvals_sweep).T

# %%
for band in range(16):
    plt.plot(U_sweep_ED, H_eigvals_sweep[band], 'red')


plt.xlabel('U')
plt.ylabel('E')
plt.title(f'Eigenvalues vs U, {x_dimension}x{y_dimension}')
# plt.ylim(jnp.min(solved_eigvals) - 0.5, jnp.max(solved_eigvals) + 0.5)

# plt.legend()
plt.show()

# %% [markdown]
# # Schur complement

# %%
def find_degeneracies(E0, tol=1E-10):

    sorted_indices = jnp.argsort(E0)
    sorted_E0 = jnp.array(E0)[sorted_indices]
    
    degeneracy_counts = []

    current_degeneracy = 1

    for i in range(1, len(sorted_E0)):
        if jnp.abs(sorted_E0[i] - sorted_E0[i - 1]) < tol:

            current_degeneracy += 1
        else:

            degeneracy_counts.append(current_degeneracy)
            current_degeneracy = 1

    degeneracy_counts.append(current_degeneracy)
    
    return degeneracy_counts

def degenerate_states(Hi, H0_eigvecs, degeneracy_counts):

    start_index = 0
    for i, count in enumerate(degeneracy_counts):
        
        P = H0_eigvecs[:, start_index:start_index+count]
        P_T = jnp.conj(P.T)
        Hi_proj = P_T @ Hi @ P

        Hi_eigvals, Hi_eigvecs = jnp.linalg.eigh(Hi_proj)
        Hi_eigvecs = P @ Hi_eigvecs
        
        if i == 0:
            print("Eigenvalues of first Hi: \n", Hi_eigvals)
        
        H0_eigvecs = H0_eigvecs.at[:, start_index:start_index + count].set(Hi_eigvecs)
        start_index += count

    return H0_eigvecs

# %%
H0 =  reduced_hubbard_model(U=0, indices=reduced_H_indices)

H0_eigvals, H0_eigvecs = jnp.linalg.eigh(H0)
print("Eigenvalues of H0: \n", jnp.round(H0_eigvals[:8], 3))

Hi = reduced_hubbard_model(U=1, indices=reduced_H_indices) - H0
# Out:
# Eigenvalues of H0:
#  [-11.2 -11.2 -11.2 -11.2 -11.2 -11.2 -11.2 -11.2]

# %%
degeneracy_counts = find_degeneracies(H0_eigvals[:], tol=1E-10)
print("Number of degerate Eigenvalues:\n", degeneracy_counts)
k = sum(degeneracy_counts[:1])

degeneracy_counts = find_degeneracies(H0_eigvals[:k], tol=1E-10)
print("Number of degerate Eigenvalues:\n", degeneracy_counts)
H0_eigvecs_updated = degenerate_states(Hi, H0_eigvecs[:, :k], degeneracy_counts)
H0_eigvals_updated = H0_eigvals[:k]

degeneracy_idx = [0, k-1]
degeneracy_dim = degeneracy_idx[1] - degeneracy_idx[0] + 1
# Out:
# Number of degerate Eigenvalues:
#  [16, 32, 16, 48, 176, 176, 36, 48, 192, 328, 192, 36]
# Number of degerate Eigenvalues:
#  [16]
# Eigenvalues of first Hi:
#  [0.33333333 0.33333333 0.33333333 0.33333333 0.33333333 0.33333333
#  0.33333333 0.44444444 0.44444444 0.44444444 0.44444444 0.55555556
#  0.55555556 0.55555556 0.55555556 0.77777778]

# %%
k = 7
H0_eigvecs_updated = H0_eigvecs_updated[:, :k]
H0_eigvals_updated = H0_eigvals[:k]

degeneracy_idx = [0, k-1]
degeneracy_dim = degeneracy_idx[1] - degeneracy_idx[0] + 1

# %%
def Schur_complement(H, E, init_eigvecs, degeneracy_idx, dim):
    degeneracy_dim = degeneracy_idx[1] - degeneracy_idx[0] + 1
    degeneracy_eigvecs = init_eigvecs[:, degeneracy_idx[0]:degeneracy_idx[1] + 1]
    Hij = jnp.conj(degeneracy_eigvecs.T) @ H @ degeneracy_eigvecs

    alpha = 1
    gamma = 1E-10
    
    O = jnp.zeros((dim, dim))
    for d in range(degeneracy_dim):
        O += jnp.outer(degeneracy_eigvecs[:, d], jnp.conj(degeneracy_eigvecs[:, d]))
    Q = jnp.eye(dim) - O
    M = alpha * O + Q @ (E * jnp.eye(dim) - H) @ Q + gamma * 1j * jnp.eye(dim)

    # C = O @ H @ O
    # print(jnp.linalg.det(C-H))
    M_inv = jnp.linalg.inv(M)

    Rij = jnp.conj(degeneracy_eigvecs.T) @ H @ Q @ M_inv @ Q @ H @ degeneracy_eigvecs

    return jnp.real(Hij + Rij - E * jnp.eye(degeneracy_dim))

# %%
def Schur_complement_qsp(H, E, init_eigvecs, degeneracy_idx, dim, poly, kappa):
    degeneracy_dim = degeneracy_idx[1] - degeneracy_idx[0] + 1
    degeneracy_eigvecs = init_eigvecs[:, degeneracy_idx[0]:degeneracy_idx[1] + 1]
    Hij = jnp.conj(degeneracy_eigvecs.T) @ H @ degeneracy_eigvecs

    alpha = 1
    gamma = 1E-10
    
    O = jnp.zeros((dim, dim))
    for d in range(degeneracy_dim):
        O += jnp.outer(degeneracy_eigvecs[:, d], jnp.conj(degeneracy_eigvecs[:, d]))
    Q = jnp.eye(dim) - O
    M = alpha * O + Q @ (E * jnp.eye(dim) - H) @ Q + gamma * 1j * jnp.eye(dim)

    N = jnp.linalg.norm(M)
    M = M / N
    
    M_eigvals, M_eigvecs = jnp.linalg.eigh(M)
    M_eigvals_inv = jnp.diag(poly(M_eigvals))
    M_inv = M_eigvecs @ M_eigvals_inv @ jnp.conj(M_eigvecs.T) * 2 * kappa / N

    Rij = jnp.conj(degeneracy_eigvecs.T) @ H @ Q @ M_inv @ Q @ H @ degeneracy_eigvecs

    return jnp.real(Hij + Rij - E * jnp.eye(degeneracy_dim))

# %%
def QHQ_spectrum(H, init_eigvecs, degeneracy_idx, dim):
    degeneracy_dim = degeneracy_idx[1] - degeneracy_idx[0] + 1
    degeneracy_eigvecs = init_eigvecs[:, degeneracy_idx[0]:degeneracy_idx[1] + 1]
    
    O = jnp.zeros((dim, dim))
    for d in range(degeneracy_dim):
        O += jnp.outer(degeneracy_eigvecs[:, d], jnp.conj(degeneracy_eigvecs[:, d]))
    Q = jnp.eye(dim) - O
    QHQ = Q @ H @ Q

    spectrum = jnp.linalg.eigh(QHQ)

    return spectrum

# %%
QHQ_eigvals, QHQ_eigvecs = QHQ_spectrum(H=H_reduced, init_eigvecs=H0_eigvecs_updated, degeneracy_idx=degeneracy_idx, dim=reduced_dim)

# %% [markdown]
# ## Eigenbranches (error $ = 10^{-3}$)

# %%
kappa = 80
error = 3
file_name = f'coef_kappa{kappa}_error1e-{error}*'
file = glob.glob(file_name)
pcoefs = loadmat(file[0])
pcoefs = pcoefs['coef_full']

pcoefs = jnp.array([coef[0] for coef in pcoefs])
poly = Chebyshev(pcoefs)

# %%
Xlim = [H_reduced_eigvals[0] - 0.1, H_reduced_eigvals[10] + 0.1]
N_plot = 100
Energy = jnp.linspace(Xlim[0], Xlim[1], N_plot)

# %%
Eigenbranches = []
for En in Energy:
    Schur = Schur_complement_qsp(H=H_reduced, E=En, init_eigvecs=H0_eigvecs_updated, degeneracy_idx=degeneracy_idx, dim=reduced_dim, poly=poly, kappa=kappa)
    sub_eigvals = jnp.linalg.eigvalsh(Schur)
    Eigenbranches.append(sub_eigvals)
Eigenbranches = jnp.array(Eigenbranches).T

# %%
plt.xlabel('E')
plt.ylabel('Eigenspectrum of Heff')
plt.xlim(Xlim[0], Xlim[1])
# plt.xlim(4, 7)
plt.ylim(-1, 1)

for Eigenbranch in Eigenbranches:
    plt.plot(Energy, Eigenbranch, 'red')

plt.axhline(y=0, color='blue')

plt.plot(H_reduced_eigvals, jnp.zeros_like(H_reduced_eigvals), 'o', color='black')
plt.plot(QHQ_eigvals, jnp.zeros_like(QHQ_eigvals), 'o', color='green', markersize=3)

plt.show()

# %% [markdown]
# # Binary search
# ### ($\Delta U = 0.4$)

# %% [markdown]
# ## error $ = 10^{-3}$

# %%
kappa = 80
error = 3
file_name = f'coef_kappa{kappa}_error1e-{error}*'
file = glob.glob(file_name)
pcoefs = loadmat(file[0])
pcoefs = pcoefs['coef_full']

pcoefs = jnp.array([coef[0] for coef in pcoefs])
poly = Chebyshev(pcoefs)

# %%
U_sweep = jnp.linspace(0, U, 11)

# %%
solved_eigvals = [[vals.item() for vals in H0_eigvals_updated]]

def binary_search_solver(Schur_complement, x0, subspace_eigvals_idx, E_cutoff=10**(-error), max_iter=100):

    def f(x):
        Schur = Schur_complement(x)
        sub_eigvals = jnp.linalg.eigvalsh(Schur)
        return sub_eigvals[subspace_eigvals_idx]

    xn = x0[subspace_eigvals_idx]
    fn = f(x0[subspace_eigvals_idx])

    # Iterative binary search
    for iteration in range(max_iter):
        # Update bounds based on fn's sign
        if fn < 0:
            upper_bound = xn
            lower_bound = fn + xn
        else:
            upper_bound = fn + xn
            lower_bound = xn

        # Update midpoint
        xn = (lower_bound + upper_bound) / 2

        # Update the function value at xn
        fn = f(xn)

        # Check for convergence
        if jnp.abs(fn) < E_cutoff:
            print(f"Converged in {iteration} iterations.")
            print(xn)
            return xn.item()

    print("Binary search did not converge within the maximum number of iterations.")
    print(xn)
    return xn.item()


for i, UU in enumerate(U_sweep):
    # Skip the first iteration
    if i == 0:
        continue
    print('solve:', i)
    
    # Construct the Hamiltonian for the coulomb = U
    H = reduced_hubbard_model(U=float(UU), indices=reduced_H_indices)
    
    # Use binary search to solve the eigenvalues of different band
    solved_eigval = []
    for subspace_eigvals_idx in range(k):
        subspace_solved_eigval = binary_search_solver(Schur_complement=lambda x: Schur_complement_qsp(H=H, E=x, init_eigvecs=H0_eigvecs_updated, degeneracy_idx=degeneracy_idx, dim=reduced_dim, poly=poly, kappa=kappa), 
                                                x0=solved_eigvals[-1], subspace_eigvals_idx=subspace_eigvals_idx)
        solved_eigval.append(subspace_solved_eigval)
    solved_eigvals.append(solved_eigval)
solved_eigvals = jnp.array(solved_eigvals).T
# Out:
# solve: 1
# Converged in 6 iterations.
# -11.072768520018759
# Converged in 7 iterations.
# -11.071477926784077
# Converged in 7 iterations.
# -11.071477926784063
# Converged in 7 iterations.
# -11.071477926784059
# Converged in 7 iterations.
# -11.071477926784043
# Converged in 7 iterations.
# -11.071253434411545
# Converged in 7 iterations.
# -11.071253434411538
# solve: 2
# Converged in 6 iterations.
# -10.953963080742403
# Converged in 6 iterations.
# -10.951185023525273
# Converged in 6 iterations.
# -10.951185023525257
# Converged in 6 iterations.
# -10.951185023525255
# Converged in 6 iterations.
# -10.951185023525236
# Converged in 6 iterations.
# -10.950324068507388
# Converged in 6 iterations.
# -10.950324068507381
# solve: 3
# Converged in 6 iterations.
# -10.843703936145957
# Converged in 6 iterations.
# -10.838200569912853
# Converged in 6 iterations.
# -10.838200569912836
# Converged in 6 iterations.
# -10.838200569912834
# Converged in 6 iterations.
# -10.838200569912818
# Converged in 6 iterations.
# -10.836343047343913
# Converged in 6 iterations.
# -10.836343047343906
# solve: 4
# Converged in 6 iterations.
# -10.74116736072895
# Converged in 6 iterations.
# -10.732534335024372
# Converged in 6 iterations.
# -10.732534335024358
# Converged in 6 iterations.
# -10.732534335024354
# Converged in 6 iterations.
# -10.732534335024337
# Converged in 6 iterations.
# -10.729380463124524
# Converged in 6 iterations.
# -10.729380463124517
# solve: 5
# Converged in 6 iterations.
# -10.645610616494462
# Converged in 6 iterations.
# -10.633706115482415
# Converged in 6 iterations.
# -10.6337061154824
# Converged in 6 iterations.
# -10.633706115482397
# Converged in 6 iterations.
# -10.633706115482383
# Converged in 6 iterations.
# -10.629014254075848
# Converged in 6 iterations.
# -10.629014254075841
# solve: 6
# Converged in 6 iterations.
# -10.556366743570479
# Converged in 6 iterations.
# -10.541243978517096
# Converged in 6 iterations.
# -10.54124397851708
# Converged in 6 iterations.
# -10.541243978517077
# Converged in 6 iterations.
# -10.541243978517063
# Converged in 6 iterations.
# -10.53482674560021
# Converged in 6 iterations.
# -10.534826745600203
# solve: 7
# Converged in 6 iterations.
# -10.472838742497682
# Converged in 6 iterations.
# -10.45469306435949
# Converged in 6 iterations.
# -10.454693064359477
# Converged in 6 iterations.
# -10.454693064359473
# Converged in 6 iterations.
# -10.454693064359459
# Converged in 6 iterations.
# -10.446411822633666
# Converged in 6 iterations.
# -10.446411822633658
# solve: 8
# Converged in 6 iterations.
# -10.394495967018708
# Converged in 6 iterations.
# -10.373619166310991
# Converged in 6 iterations.
# -10.373619166310979
# Converged in 6 iterations.
# -10.373619166310977
# Converged in 6 iterations.
# -10.37361916631096
# Converged in 6 iterations.
# -10.363377737143402
# Converged in 6 iterations.
# -10.363377737143395
# solve: 9
# Converged in 5 iterations.
# -10.32136633719325
# Converged in 6 iterations.
# -10.297611115529989
# Converged in 6 iterations.
# -10.297611115529977
# Converged in 6 iterations.
# -10.297611115529971
# Converged in 6 iterations.
# -10.297611115529957
# Converged in 6 iterations.
# -10.285349385214989
# Converged in 6 iterations.
# -10.285349385214982
# solve: 10
# Converged in 5 iterations.
# -10.252010594326443
# Converged in 5 iterations.
# -10.226744560302397
# Converged in 5 iterations.
# -10.226744560302386
# Converged in 5 iterations.
# -10.226744560302382
# Converged in 5 iterations.
# -10.226744560302368
# Converged in 5 iterations.
# -10.21245270977527
# Converged in 5 iterations.
# -10.212452709775262

# %%
for band in range(degeneracy_idx[0], degeneracy_idx[1] + 1):
    plt.plot(U_sweep_ED, H_eigvals_sweep[band], 'red')
for band in range(degeneracy_idx[0], degeneracy_idx[1] + 1):
    plt.plot(U_sweep, solved_eigvals[band], 'black', linestyle='dashed')

plt.plot(U_sweep_ED[0], H_eigvals_sweep[band][0], 'red', label='ED')
plt.plot(U_sweep[0], solved_eigvals[0, 0], 'black', linestyle='dashed', label='Binary')

plt.xlabel('U')
plt.ylabel('E')
plt.title(f'Eigenvalues vs U, {x_dimension}x{y_dimension}')
# plt.ylim(jnp.min(solved_eigvals) - 0.5, jnp.max(solved_eigvals) + 0.5)

plt.legend()
plt.show()

# %%
for i in range(7):
    print(solved_eigvals.T[-1, i]-H_eigvals_sweep.T[-1, i])
# Out:
# -0.0009041061233645564
# 0.00046859802510113013
# 0.00046859802510468285
# 0.00046859802510823556
# 0.0004685980251188937
# -0.0015476902932647363
# -0.0015476902932576309

# %% [markdown]
# ## error $ = 10^{-6}$

# %%
kappa = 80
error = 6
file_name = f'coef_kappa{kappa}_error1e-{error}*'
file = glob.glob(file_name)
pcoefs = loadmat(file[0])
pcoefs = pcoefs['coef_full']

pcoefs = jnp.array([coef[0] for coef in pcoefs])
poly = Chebyshev(pcoefs)

# %%
U_sweep = jnp.linspace(0, U, 11)

# %%
solved_eigvals = [[vals.item() for vals in H0_eigvals_updated]]

def binary_search_solver(Schur_complement, x0, subspace_eigvals_idx, E_cutoff=10**(-error), max_iter=100):

    def f(x):
        Schur = Schur_complement(x)
        sub_eigvals = jnp.linalg.eigvalsh(Schur)
        return sub_eigvals[subspace_eigvals_idx]

    xn = x0[subspace_eigvals_idx]
    fn = f(x0[subspace_eigvals_idx])

    # Iterative binary search
    for iteration in range(max_iter):
        # Update bounds based on fn's sign
        if fn < 0:
            upper_bound = xn
            lower_bound = fn + xn
        else:
            upper_bound = fn + xn
            lower_bound = xn

        # Update midpoint
        xn = (lower_bound + upper_bound) / 2

        # Update the function value at xn
        fn = f(xn)

        # Check for convergence
        if jnp.abs(fn) < E_cutoff:
            print(f"Converged in {iteration} iterations.")
            print(xn)
            return xn.item()

    print("Binary search did not converge within the maximum number of iterations.")
    print(xn)
    return xn.item()


for i, UU in enumerate(U_sweep):
    # Skip the first iteration
    if i == 0:
        continue
    print('solve:', i)
    
    # Construct the Hamiltonian for the coulomb = U
    H = reduced_hubbard_model(U=float(UU), indices=reduced_H_indices)
    
    # Use binary search to solve the eigenvalues of different band
    solved_eigval = []
    for subspace_eigvals_idx in range(k):
        subspace_solved_eigval = binary_search_solver(Schur_complement=lambda x: Schur_complement_qsp(H=H, E=x, init_eigvecs=H0_eigvecs_updated, degeneracy_idx=degeneracy_idx, dim=reduced_dim, poly=poly, kappa=kappa), 
                                                x0=solved_eigvals[-1], subspace_eigvals_idx=subspace_eigvals_idx)
        solved_eigval.append(subspace_solved_eigval)
    solved_eigvals.append(solved_eigval)
solved_eigvals = jnp.array(solved_eigvals).T
# Out:
# solve: 1
# Converged in 16 iterations.
# -11.071772544296678
# Converged in 16 iterations.
# -11.07099060383943
# Converged in 16 iterations.
# -11.070990603839416
# Converged in 16 iterations.
# -11.070990603839412
# Converged in 16 iterations.
# -11.070990603839396
# Converged in 16 iterations.
# -11.07074957183617
# Converged in 16 iterations.
# -11.070749571836162
# solve: 2
# Converged in 16 iterations.
# -10.9530377672885
# Converged in 16 iterations.
# -10.950303141622983
# Converged in 16 iterations.
# -10.950303141622967
# Converged in 16 iterations.
# -10.950303141622964
# Converged in 16 iterations.
# -10.950303141622946
# Converged in 16 iterations.
# -10.949376369548363
# Converged in 16 iterations.
# -10.949376369548357
# solve: 3
# Converged in 16 iterations.
# -10.84283103171801
# Converged in 16 iterations.
# -10.837446887321526
# Converged in 16 iterations.
# -10.837446887321512
# Converged in 16 iterations.
# -10.837446887321509
# Converged in 16 iterations.
# -10.837446887321493
# Converged in 16 iterations.
# -10.835446910963801
# Converged in 16 iterations.
# -10.835446910963796
# solve: 4
# Converged in 16 iterations.
# -10.740312408877049
# Converged in 16 iterations.
# -10.731928435720858
# Converged in 16 iterations.
# -10.731928435720844
# Converged in 16 iterations.
# -10.731928435720839
# Converged in 16 iterations.
# -10.731928435720823
# Converged in 16 iterations.
# -10.72852472664203
# Converged in 16 iterations.
# -10.728524726642021
# solve: 5
# Converged in 16 iterations.
# -10.644747770581201
# Converged in 16 iterations.
# -10.633261410207147
# Converged in 16 iterations.
# -10.633261410207133
# Converged in 16 iterations.
# -10.63326141020713
# Converged in 16 iterations.
# -10.633261410207115
# Converged in 16 iterations.
# -10.628178190737255
# Converged in 16 iterations.
# -10.628178190737248
# solve: 6
# Converged in 16 iterations.
# -10.555492403227326
# Converged in 16 iterations.
# -10.540973214169671
# Converged in 16 iterations.
# -10.540973214169657
# Converged in 16 iterations.
# -10.540973214169654
# Converged in 16 iterations.
# -10.54097321416964
# Converged in 16 iterations.
# -10.533985980771806
# Converged in 16 iterations.
# -10.5339859807718
# solve: 7
# Converged in 15 iterations.
# -10.471978001273191
# Converged in 15 iterations.
# -10.45461049796605
# Converged in 15 iterations.
# -10.454610497966035
# Converged in 15 iterations.
# -10.454610497966032
# Converged in 15 iterations.
# -10.454610497966017
# Converged in 16 iterations.
# -10.445541281152913
# Converged in 16 iterations.
# -10.445541281152908
# solve: 8
# Converged in 15 iterations.
# -10.39369964699746
# Converged in 15 iterations.
# -10.373740661557587
# Converged in 15 iterations.
# -10.373740661557573
# Converged in 15 iterations.
# -10.373740661557571
# Converged in 15 iterations.
# -10.373740661557555
# Converged in 15 iterations.
# -10.362455285532745
# Converged in 15 iterations.
# -10.362455285532736
# solve: 9
# Converged in 15 iterations.
# -10.320209662869061
# Converged in 15 iterations.
# -10.29795704932277
# Converged in 15 iterations.
# -10.297957049322758
# Converged in 15 iterations.
# -10.297957049322752
# Converged in 15 iterations.
# -10.297957049322736
# Converged in 15 iterations.
# -10.28435744918799
# Converged in 15 iterations.
# -10.284357449187983
# solve: 10
# Converged in 15 iterations.
# -10.251107987983335
# Converged in 15 iterations.
# -10.226877963258795
# Converged in 15 iterations.
# -10.226877963258783
# Converged in 15 iterations.
# -10.22687796325878
# Converged in 15 iterations.
# -10.226877963258763
# Converged in 15 iterations.
# -10.210899531518194
# Converged in 15 iterations.
# -10.210899531518187

# %%
for band in range(degeneracy_idx[0], degeneracy_idx[1] + 1):
    plt.plot(U_sweep_ED, H_eigvals_sweep[band], 'red')
for band in range(degeneracy_idx[0], degeneracy_idx[1] + 1):
    plt.plot(U_sweep, solved_eigvals[band], 'black', linestyle='dashed')

plt.plot(U_sweep_ED[0], H_eigvals_sweep[band][0], 'red', label='ED')
plt.plot(U_sweep[0], solved_eigvals[0, 0], 'black', linestyle='dashed', label='Binary')

plt.xlabel('U')
plt.ylabel('E')
plt.title(f'Eigenvalues vs U, {x_dimension}x{y_dimension}')
# plt.ylim(jnp.min(solved_eigvals) - 0.5, jnp.max(solved_eigvals) + 0.5)

plt.legend()
plt.show()

# %%
for i in range(7):
    print(solved_eigvals.T[-1, i]-H_eigvals_sweep.T[-1, i])
# Out:
# -1.4997802573191166e-06
# 0.00033519506870227644
# 0.0003351950687076055
# 0.00033519506871115823
# 0.0003351950687235927
# 5.487963811390273e-06
# 5.487963816719343e-06

# %% [markdown]
# ## error $ = 10^{-8}$

# %%
kappa = 80
error = 8
file_name = f'coef_kappa{kappa}_error1e-{error}*'
file = glob.glob(file_name)
pcoefs = loadmat(file[0])
pcoefs = pcoefs['coef_full']

pcoefs = jnp.array([coef[0] for coef in pcoefs])
poly = Chebyshev(pcoefs)

# %%
U_sweep = jnp.linspace(0, U, 11)

# %%
solved_eigvals = [[vals.item() for vals in H0_eigvals_updated]]

def binary_search_solver(Schur_complement, x0, subspace_eigvals_idx, E_cutoff=10**(-error), max_iter=100):

    def f(x):
        Schur = Schur_complement(x)
        sub_eigvals = jnp.linalg.eigvalsh(Schur)
        return sub_eigvals[subspace_eigvals_idx]

    xn = x0[subspace_eigvals_idx]
    fn = f(x0[subspace_eigvals_idx])

    # Iterative binary search
    for iteration in range(max_iter):
        # Update bounds based on fn's sign
        if fn < 0:
            upper_bound = xn
            lower_bound = fn + xn
        else:
            upper_bound = fn + xn
            lower_bound = xn

        # Update midpoint
        xn = (lower_bound + upper_bound) / 2

        # Update the function value at xn
        fn = f(xn)

        # Check for convergence
        if jnp.abs(fn) < E_cutoff:
            print(f"Converged in {iteration} iterations.")
            print(xn)
            return xn.item()

    print("Binary search did not converge within the maximum number of iterations.")
    print(xn)
    return xn.item()


for i, UU in enumerate(U_sweep):
    # Skip the first iteration
    if i == 0:
        continue
    print('solve:', i)
    
    # Construct the Hamiltonian for the coulomb = U
    H = reduced_hubbard_model(U=float(UU), indices=reduced_H_indices)
    
    # Use binary search to solve the eigenvalues of different band
    solved_eigval = []
    for subspace_eigvals_idx in range(k):
        subspace_solved_eigval = binary_search_solver(Schur_complement=lambda x: Schur_complement_qsp(H=H, E=x, init_eigvecs=H0_eigvecs_updated, degeneracy_idx=degeneracy_idx, dim=reduced_dim, poly=poly, kappa=kappa), 
                                                x0=solved_eigvals[-1], subspace_eigvals_idx=subspace_eigvals_idx)
        solved_eigval.append(subspace_solved_eigval)
    solved_eigvals.append(solved_eigval)
solved_eigvals = jnp.array(solved_eigvals).T
# Out:
# solve: 1
# Converged in 23 iterations.
# -11.071771597521206
# Converged in 23 iterations.
# -11.070989427052098
# Converged in 23 iterations.
# -11.070989427052083
# Converged in 23 iterations.
# -11.07098942705208
# Converged in 23 iterations.
# -11.070989427052066
# Converged in 23 iterations.
# -11.070748608561226
# Converged in 23 iterations.
# -11.070748608561217
# solve: 2
# Converged in 23 iterations.
# -10.953036956392257
# Converged in 23 iterations.
# -10.950300094509673
# Converged in 23 iterations.
# -10.95030009450966
# Converged in 23 iterations.
# -10.950300094509656
# Converged in 23 iterations.
# -10.950300094509636
# Converged in 23 iterations.
# -10.949375489738088
# Converged in 23 iterations.
# -10.949375489738081
# solve: 3
# Converged in 23 iterations.
# -10.84283036126605
# Converged in 23 iterations.
# -10.837437061829624
# Converged in 23 iterations.
# -10.837437061829608
# Converged in 23 iterations.
# -10.837437061829606
# Converged in 23 iterations.
# -10.837437061829588
# Converged in 23 iterations.
# -10.835446055062285
# Converged in 23 iterations.
# -10.835446055062278
# solve: 4
# Converged in 23 iterations.
# -10.740311863553028
# Converged in 23 iterations.
# -10.731902974353655
# Converged in 23 iterations.
# -10.731902974353641
# Converged in 23 iterations.
# -10.731902974353636
# Converged in 23 iterations.
# -10.73190297435362
# Converged in 23 iterations.
# -10.728523732359665
# Converged in 23 iterations.
# -10.728523732359658
# solve: 5
# Converged in 22 iterations.
# -10.644747314810285
# Converged in 22 iterations.
# -10.63320733145163
# Converged in 22 iterations.
# -10.633207331451615
# Converged in 22 iterations.
# -10.633207331451612
# Converged in 22 iterations.
# -10.633207331451594
# Converged in 22 iterations.
# -10.628176764199752
# Converged in 22 iterations.
# -10.628176764199743
# solve: 6
# Converged in 22 iterations.
# -10.555491951137395
# Converged in 22 iterations.
# -10.540873434511731
# Converged in 22 iterations.
# -10.540873434511717
# Converged in 22 iterations.
# -10.540873434511713
# Converged in 22 iterations.
# -10.540873434511695
# Converged in 22 iterations.
# -10.53398364683311
# Converged in 22 iterations.
# -10.533983646833104
# solve: 7
# Converged in 22 iterations.
# -10.47197697260696
# Converged in 22 iterations.
# -10.454443357880539
# Converged in 22 iterations.
# -10.454443357880525
# Converged in 22 iterations.
# -10.454443357880521
# Converged in 22 iterations.
# -10.454443357880507
# Converged in 22 iterations.
# -10.445537357706726
# Converged in 22 iterations.
# -10.445537357706717
# solve: 8
# Converged in 22 iterations.
# -10.393698467792888
# Converged in 22 iterations.
# -10.373481181148232
# Converged in 22 iterations.
# -10.373481181148222
# Converged in 22 iterations.
# -10.373481181148218
# Converged in 22 iterations.
# -10.373481181148202
# Converged in 22 iterations.
# -10.362448389933586
# Converged in 22 iterations.
# -10.36244838993358
# solve: 9
# Converged in 21 iterations.
# -10.320208296465221
# Converged in 21 iterations.
# -10.297574913812579
# Converged in 21 iterations.
# -10.297574913812564
# Converged in 21 iterations.
# -10.29757491381256
# Converged in 21 iterations.
# -10.297574913812547
# Converged in 21 iterations.
# -10.284346826673454
# Converged in 21 iterations.
# -10.284346826673447
# solve: 10
# Converged in 21 iterations.
# -10.251106492084713
# Converged in 21 iterations.
# -10.226337384899455
# Converged in 21 iterations.
# -10.226337384899445
# Converged in 21 iterations.
# -10.226337384899441
# Converged in 21 iterations.
# -10.226337384899427
# Converged in 21 iterations.
# -10.210883553110506
# Converged in 21 iterations.
# -10.210883553110497

# %%
for band in range(degeneracy_idx[0], degeneracy_idx[1] + 1):
    plt.plot(U_sweep_ED, H_eigvals_sweep[band], 'red')
for band in range(degeneracy_idx[0], degeneracy_idx[1] + 1):
    plt.plot(U_sweep, solved_eigvals[band], 'black', linestyle='dashed')

plt.plot(U_sweep_ED[0], H_eigvals_sweep[band][0], 'red', label='ED')
plt.plot(U_sweep[0], solved_eigvals[0, 0], 'black', linestyle='dashed', label='Binary')

plt.xlabel('U')
plt.ylabel('E')
plt.title(f'Eigenvalues vs U, {x_dimension}x{y_dimension}')
# plt.ylim(jnp.min(solved_eigvals) - 0.5, jnp.max(solved_eigvals) + 0.5)

plt.legend()
plt.show()

# %%
for i in range(7):
    print(solved_eigvals.T[-1, i]-H_eigvals_sweep.T[-1, i])
# Out:
# -3.881634569324888e-09
# 0.0008757734280422369
# 0.0008757734280457896
# 0.0008757734280493423
# 0.0008757734280600005
# 2.146637149991193e-05
# 2.1466371507017357e-05

# %% [markdown]
# ## $\Delta U = 4$

# %% [markdown]
# ## error $ = 10^{-3}$

# %%
kappa = 80
error = 3
file_name = f'coef_kappa{kappa}_error1e-{error}*'
file = glob.glob(file_name)
pcoefs = loadmat(file[0])
pcoefs = pcoefs['coef_full']

pcoefs = jnp.array([coef[0] for coef in pcoefs])
poly = Chebyshev(pcoefs)

# %%
U_sweep = jnp.linspace(0, U, 2)

# %%
solved_eigvals = [[vals.item() for vals in H0_eigvals_updated]]

def binary_search_solver(Schur_complement, x0, subspace_eigvals_idx, E_cutoff=10**(-error), max_iter=100):

    def f(x):
        Schur = Schur_complement(x)
        sub_eigvals = jnp.linalg.eigvalsh(Schur)
        return sub_eigvals[subspace_eigvals_idx]

    xn = x0[subspace_eigvals_idx]
    fn = f(x0[subspace_eigvals_idx])

    # Iterative binary search
    for iteration in range(max_iter):
        # Update bounds based on fn's sign
        if fn < 0:
            upper_bound = xn
            lower_bound = fn + xn
        else:
            upper_bound = fn + xn
            lower_bound = xn

        # Update midpoint
        xn = (lower_bound + upper_bound) / 2

        # Update the function value at xn
        fn = f(xn)

        # Check for convergence
        if jnp.abs(fn) < E_cutoff:
            print(f"Converged in {iteration} iterations.")
            print(xn)
            return xn.item()

    print("Binary search did not converge within the maximum number of iterations.")
    print(xn)
    return xn.item()


for i, UU in enumerate(U_sweep):
    # Skip the first iteration
    if i == 0:
        continue
    print('solve:', i)
    
    # Construct the Hamiltonian for the coulomb = U
    H = reduced_hubbard_model(U=float(UU), indices=reduced_H_indices)
    
    # Use binary search to solve the eigenvalues of different band
    solved_eigval = []
    for subspace_eigvals_idx in range(k):
        subspace_solved_eigval = binary_search_solver(Schur_complement=lambda x: Schur_complement_qsp(H=H, E=x, init_eigvecs=H0_eigvecs_updated, degeneracy_idx=degeneracy_idx, dim=reduced_dim, poly=poly, kappa=kappa), 
                                                x0=solved_eigvals[-1], subspace_eigvals_idx=subspace_eigvals_idx)
        solved_eigval.append(subspace_solved_eigval)
    solved_eigvals.append(solved_eigval)
solved_eigvals = jnp.array(solved_eigvals).T
# Out:
# solve: 1
# Converged in 9 iterations.
# -10.251776396862091
# Converged in 9 iterations.
# -10.22650602769937
# Converged in 9 iterations.
# -10.226506027699358
# Converged in 9 iterations.
# -10.226506027699353
# Converged in 9 iterations.
# -10.226506027699338
# Converged in 9 iterations.
# -10.212201339468447
# Converged in 9 iterations.
# -10.21220133946844

# %%
for band in range(degeneracy_idx[0], degeneracy_idx[1] + 1):
    plt.plot(U_sweep_ED, H_eigvals_sweep[band], 'red')
for band in range(degeneracy_idx[0], degeneracy_idx[1] + 1):
    plt.plot(U_sweep, solved_eigvals[band], 'black', linestyle='dashed')

plt.plot(U_sweep_ED[0], H_eigvals_sweep[band][0], 'red', label='ED')
plt.plot(U_sweep[0], solved_eigvals[0, 0], 'black', linestyle='dashed', label='Binary')

plt.xlabel('U')
plt.ylabel('E')
plt.title(f'Eigenvalues vs U, {x_dimension}x{y_dimension}')
# plt.ylim(jnp.min(solved_eigvals) - 0.5, jnp.max(solved_eigvals) + 0.5)

plt.legend()
plt.show()

# %%
for i in range(7):
    print(solved_eigvals.T[-1, i]-H_eigvals_sweep.T[-1, i])
# Out:
# -0.0006699086590131742
# 0.0007071306281272172
# 0.0007071306281325462
# 0.0007071306281378753
# 0.0007071306281485334
# -0.0012963199864408637
# -0.0012963199864355346

# %% [markdown]
# # Wegstien's method
# ### ($\Delta U = 0.4$)

# %% [markdown]
# ## error $ = 10^{-3}$

# %%
kappa = 80
error = 3
file_name = f'coef_kappa{kappa}_error1e-{error}*'
file = glob.glob(file_name)
pcoefs = loadmat(file[0])
pcoefs = pcoefs['coef_full']

pcoefs = jnp.array([coef[0] for coef in pcoefs])
poly = Chebyshev(pcoefs)

# %%
U_sweep = jnp.linspace(0, U, 11)

# %%
solved_eigvals = [[vals.item() for vals in H0_eigvals_updated]]

def Wegstein_solver(Schur_complement, x0, subspace_eigvals_idx, E_cutoff=10**(-error), max_iter=100):

    def f(x):
        Schur = Schur_complement(x)
        sub_eigvals = jnp.linalg.eigvalsh(Schur)
        return sub_eigvals[subspace_eigvals_idx] + x
    
    # Initialize xn and fn
    xn = [x0[subspace_eigvals_idx], f(x0[subspace_eigvals_idx])]
    fn = [xn[1], f(xn[1])]    
    
    for i in range(1, max_iter):
        
        x_new = (xn[i-1]*fn[i] - xn[i]*fn[i-1]) / (xn[i-1] + fn[i] - xn[i] - fn[i-1])
        xn.append(x_new)
        fn.append(f(x_new))
        
        # If the energy difference is less than cutoff, the algorithm converge
        if abs(x_new - xn[i]) < E_cutoff:
            print(f"Converged in {i} iterations.")
            print(fn[-1])
            return fn[-1]
    
    print("Wegstein method did not converge within the maximum number of iterations.")
    print(fn[-1])   
    return fn[-1]


for i, UU in enumerate(U_sweep):
    # Skip the first iteration
    if i == 0:
        continue
    print('solve:', i)
    
    # Construct the Hamiltonian for the coulomb = U
    H = reduced_hubbard_model(U=float(UU), indices=reduced_H_indices)
    
    # Use binary search to solve the eigenvalues of different band
    solved_eigval = []
    for subspace_eigvals_idx in range(k):
        subspace_solved_eigval = Wegstein_solver(Schur_complement=lambda x: Schur_complement_qsp(H=H, E=x, init_eigvecs=H0_eigvecs_updated, degeneracy_idx=degeneracy_idx, dim=reduced_dim, poly=poly, kappa=kappa), 
                                                x0=solved_eigvals[-1], subspace_eigvals_idx=subspace_eigvals_idx)
        solved_eigval.append(subspace_solved_eigval)
    solved_eigvals.append(solved_eigval)
solved_eigvals = jnp.array(solved_eigvals).T
# Out:
# solve: 1
# Converged in 1 iterations.
# -11.071771112866408
# Converged in 1 iterations.
# -11.070976135026593
# Converged in 1 iterations.
# -11.07097613502658
# Converged in 1 iterations.
# -11.070976135026577
# Converged in 1 iterations.
# -11.070976135026559
# Converged in 1 iterations.
# -11.070750552175943
# Converged in 1 iterations.
# -11.070750552175936
# solve: 2
# Converged in 1 iterations.
# -10.953042784185415
# Converged in 1 iterations.
# -10.950251850009398
# Converged in 1 iterations.
# -10.950251850009384
# Converged in 1 iterations.
# -10.95025185000938
# Converged in 1 iterations.
# -10.950251850009362
# Converged in 1 iterations.
# -10.949384605359796
# Converged in 1 iterations.
# -10.94938460535979
# solve: 3
# Converged in 1 iterations.
# -10.842865009329511
# Converged in 1 iterations.
# -10.837339175132383
# Converged in 1 iterations.
# -10.837339175132367
# Converged in 1 iterations.
# -10.837339175132364
# Converged in 1 iterations.
# -10.837339175132348
# Converged in 1 iterations.
# -10.83547136576424
# Converged in 1 iterations.
# -10.835471365764233
# solve: 4
# Converged in 1 iterations.
# -10.740404736065615
# Converged in 1 iterations.
# -10.73174694867807
# Converged in 1 iterations.
# -10.731746948678055
# Converged in 1 iterations.
# -10.731746948678053
# Converged in 1 iterations.
# -10.731746948678037
# Converged in 1 iterations.
# -10.728579271060998
# Converged in 1 iterations.
# -10.72857927106099
# solve: 5
# Converged in 2 iterations.
# -10.644918602143978
# Converged in 2 iterations.
# -10.632989746081638
# Converged in 2 iterations.
# -10.63298974608157
# Converged in 2 iterations.
# -10.632989746081469
# Converged in 2 iterations.
# -10.632989746081337
# Converged in 2 iterations.
# -10.628281189624357
# Converged in 2 iterations.
# -10.628281189624259
# solve: 6
# Converged in 2 iterations.
# -10.555739428726053
# Converged in 2 iterations.
# -10.540594649463511
# Converged in 2 iterations.
# -10.5405946494638
# Converged in 2 iterations.
# -10.540594649463841
# Converged in 2 iterations.
# -10.540594649463985
# Converged in 2 iterations.
# -10.534158535062607
# Converged in 2 iterations.
# -10.534158535062277
# solve: 7
# Converged in 2 iterations.
# -10.472270268578123
# Converged in 2 iterations.
# -10.45410620720031
# Converged in 2 iterations.
# -10.454106207200214
# Converged in 2 iterations.
# -10.454106207200072
# Converged in 2 iterations.
# -10.45410620720003
# Converged in 2 iterations.
# -10.445804599717173
# Converged in 2 iterations.
# -10.445804599716917
# solve: 8
# Converged in 2 iterations.
# -10.393980721454176
# Converged in 2 iterations.
# -10.37308991332734
# Converged in 2 iterations.
# -10.37308991332733
# Converged in 2 iterations.
# -10.373089913327586
# Converged in 2 iterations.
# -10.373089913327545
# Converged in 2 iterations.
# -10.36282728327231
# Converged in 2 iterations.
# -10.362827283272612
# solve: 9
# Converged in 2 iterations.
# -10.320402727757045
# Converged in 2 iterations.
# -10.297134525571527
# Converged in 2 iterations.
# -10.29713452557184
# Converged in 2 iterations.
# -10.29713452557153
# Converged in 2 iterations.
# -10.297134525572055
# Converged in 2 iterations.
# -10.28485132371164
# Converged in 2 iterations.
# -10.284851323711987
# solve: 10
# Converged in 2 iterations.
# -10.25112519712698
# Converged in 2 iterations.
# -10.225853466599556
# Converged in 2 iterations.
# -10.225853466599252
# Converged in 2 iterations.
# -10.225853466599311
# Converged in 2 iterations.
# -10.225853466599455
# Converged in 2 iterations.
# -10.21152006079113
# Converged in 2 iterations.
# -10.211520060791344

# %%
for band in range(degeneracy_idx[0], degeneracy_idx[1] + 1):
    plt.plot(U_sweep_ED, H_eigvals_sweep[band], 'red')
for band in range(degeneracy_idx[0], degeneracy_idx[1] + 1):
    plt.plot(U_sweep, solved_eigvals[band], 'black', linestyle='dashed')

plt.plot(U_sweep_ED[0], H_eigvals_sweep[band][0], 'red', label='ED')
plt.plot(U_sweep[0], solved_eigvals[0, 0], 'black', linestyle='dashed', label='Wegstein')

plt.xlabel('U')
plt.ylabel('E')
plt.title(f'Eigenvalues vs U, {x_dimension}x{y_dimension}')
# plt.ylim(jnp.min(solved_eigvals) - 0.5, jnp.max(solved_eigvals) + 0.5)

plt.legend()
plt.show()

# %%
for i in range(7):
    print(solved_eigvals.T[-1, i]-H_eigvals_sweep.T[-1, i])
# Out:
# -1.8708923901655794e-05
# 0.001359691727941481
# 0.0013596917282381327
# 0.001359691728179513
# 0.0013596917280320753
# -0.0006150413091248197
# -0.0006150413093397589

# %% [markdown]
# ## error $ = 10^{-6}$

# %%
kappa = 80
error = 6
file_name = f'coef_kappa{kappa}_error1e-{error}*'
file = glob.glob(file_name)
pcoefs = loadmat(file[0])
pcoefs = pcoefs['coef_full']

pcoefs = jnp.array([coef[0] for coef in pcoefs])
poly = Chebyshev(pcoefs)

# %%
U_sweep = jnp.linspace(0, U, 11)

# %%
solved_eigvals = [[vals.item() for vals in H0_eigvals_updated]]

def Wegstein_solver(Schur_complement, x0, subspace_eigvals_idx, E_cutoff=10**(-error), max_iter=100):

    def f(x):
        Schur = Schur_complement(x)
        sub_eigvals = jnp.linalg.eigvalsh(Schur)
        return sub_eigvals[subspace_eigvals_idx] + x
    
    # Initialize xn and fn
    xn = [x0[subspace_eigvals_idx], f(x0[subspace_eigvals_idx])]
    fn = [xn[1], f(xn[1])]    
    
    for i in range(1, max_iter):
        
        x_new = (xn[i-1]*fn[i] - xn[i]*fn[i-1]) / (xn[i-1] + fn[i] - xn[i] - fn[i-1])
        xn.append(x_new)
        fn.append(f(x_new))
        
        # If the energy difference is less than cutoff, the algorithm converge
        if abs(x_new - xn[i]) < E_cutoff:
            print(f"Converged in {i} iterations.")
            print(fn[-1])
            return fn[-1]
    
    print("Wegstein method did not converge within the maximum number of iterations.")
    print(fn[-1])   
    return fn[-1]


for i, UU in enumerate(U_sweep):
    # Skip the first iteration
    if i == 0:
        continue
    print('solve:', i)
    
    # Construct the Hamiltonian for the coulomb = U
    H = reduced_hubbard_model(U=float(UU), indices=reduced_H_indices)
    
    # Use binary search to solve the eigenvalues of different band
    solved_eigval = []
    for subspace_eigvals_idx in range(k):
        subspace_solved_eigval = Wegstein_solver(Schur_complement=lambda x: Schur_complement_qsp(H=H, E=x, init_eigvecs=H0_eigvecs_updated, degeneracy_idx=degeneracy_idx, dim=reduced_dim, poly=poly, kappa=kappa), 
                                                x0=solved_eigvals[-1], subspace_eigvals_idx=subspace_eigvals_idx)
        solved_eigval.append(subspace_solved_eigval)
    solved_eigvals.append(solved_eigval)
solved_eigvals = jnp.array(solved_eigvals).T
# Out:
# solve: 1
# Converged in 2 iterations.
# -11.071771576365931
# Converged in 2 iterations.
# -11.070989629182476
# Converged in 2 iterations.
# -11.0709896291825
# Converged in 2 iterations.
# -11.070989629182579
# Converged in 2 iterations.
# -11.070989629182243
# Converged in 2 iterations.
# -11.070748593987894
# Converged in 2 iterations.
# -11.070748593987958
# solve: 2
# Converged in 2 iterations.
# -10.953036896568479
# Converged in 2 iterations.
# -10.950302254980956
# Converged in 2 iterations.
# -10.9503022549809
# Converged in 2 iterations.
# -10.950302254980791
# Converged in 2 iterations.
# -10.950302254980718
# Converged in 2 iterations.
# -10.94937547311398
# Converged in 2 iterations.
# -10.949375473114102
# solve: 3
# Converged in 2 iterations.
# -10.842830257862836
# Converged in 2 iterations.
# -10.83744609386347
# Converged in 2 iterations.
# -10.837446093863655
# Converged in 2 iterations.
# -10.837446093863537
# Converged in 2 iterations.
# -10.837446093863504
# Converged in 2 iterations.
# -10.835446100846449
# Converged in 2 iterations.
# -10.835446100846431
# solve: 4
# Converged in 2 iterations.
# -10.740311727478492
# Converged in 2 iterations.
# -10.731927735584533
# Converged in 2 iterations.
# -10.731927735584305
# Converged in 2 iterations.
# -10.73192773558453
# Converged in 2 iterations.
# -10.731927735584332
# Converged in 2 iterations.
# -10.728524003597403
# Converged in 2 iterations.
# -10.728524003597363
# solve: 5
# Converged in 2 iterations.
# -10.644747174850973
# Converged in 2 iterations.
# -10.633260799752321
# Converged in 2 iterations.
# -10.633260799752213
# Converged in 2 iterations.
# -10.633260799752408
# Converged in 2 iterations.
# -10.633260799752295
# Converged in 2 iterations.
# -10.628177552302523
# Converged in 2 iterations.
# -10.628177552302663
# solve: 6
# Converged in 2 iterations.
# -10.555491885198261
# Converged in 2 iterations.
# -10.540972687196332
# Converged in 2 iterations.
# -10.54097268719629
# Converged in 2 iterations.
# -10.540972687196321
# Converged in 2 iterations.
# -10.540972687196174
# Converged in 2 iterations.
# -10.533985422186609
# Converged in 2 iterations.
# -10.533985422186607
# solve: 7
# Converged in 2 iterations.
# -10.471977085236306
# Converged in 2 iterations.
# -10.454609575230533
# Converged in 2 iterations.
# -10.45460957523045
# Converged in 2 iterations.
# -10.454609575230755
# Converged in 2 iterations.
# -10.454609575230513
# Converged in 2 iterations.
# -10.445540796186217
# Converged in 2 iterations.
# -10.445540796186366
# solve: 8
# Converged in 2 iterations.
# -10.393698852109754
# Converged in 2 iterations.
# -10.373739872257396
# Converged in 2 iterations.
# -10.373739872257769
# Converged in 2 iterations.
# -10.373739872257762
# Converged in 2 iterations.
# -10.373739872257513
# Converged in 2 iterations.
# -10.362454428083971
# Converged in 2 iterations.
# -10.362454428084106
# solve: 9
# Converged in 2 iterations.
# -10.320208974346055
# Converged in 2 iterations.
# -10.297956377417764
# Converged in 2 iterations.
# -10.297956377418027
# Converged in 2 iterations.
# -10.297956377417819
# Converged in 2 iterations.
# -10.297956377417883
# Converged in 2 iterations.
# -10.284356709404959
# Converged in 2 iterations.
# -10.284356709405134
# solve: 10
# Converged in 2 iterations.
# -10.251107392245816
# Converged in 2 iterations.
# -10.226877393361416
# Converged in 2 iterations.
# -10.22687739336164
# Converged in 2 iterations.
# -10.22687739336201
# Converged in 2 iterations.
# -10.226877393362036
# Converged in 2 iterations.
# -10.210898895743522
# Converged in 2 iterations.
# -10.210898895743489

# %%
for band in range(degeneracy_idx[0], degeneracy_idx[1] + 1):
    plt.plot(U_sweep_ED, H_eigvals_sweep[band], 'red')
for band in range(degeneracy_idx[0], degeneracy_idx[1] + 1):
    plt.plot(U_sweep, solved_eigvals[band], 'black', linestyle='dashed')

plt.plot(U_sweep_ED[0], H_eigvals_sweep[band][0], 'red', label='ED')
plt.plot(U_sweep[0], solved_eigvals[0, 0], 'black', linestyle='dashed', label='Wegstein')

plt.xlabel('U')
plt.ylabel('E')
plt.title(f'Eigenvalues vs U, {x_dimension}x{y_dimension}')
# plt.ylim(jnp.min(solved_eigvals) - 0.5, jnp.max(solved_eigvals) + 0.5)

plt.legend()
plt.show()

# %%
for i in range(7):
    print(solved_eigvals.T[-1, i]-H_eigvals_sweep.T[-1, i])
# Out:
# -9.040427375595073e-07
# 0.0003357649660813422
# 0.0003357649658504158
# 0.0003357649654809336
# 0.00033576496545073553
# 6.1237384834100794e-06
# 6.1237385153845025e-06

# %% [markdown]
# ## error $ = 10^{-8}$

# %%
kappa = 80
error = 8
file_name = f'coef_kappa{kappa}_error1e-{error}*'
file = glob.glob(file_name)
pcoefs = loadmat(file[0])
pcoefs = pcoefs['coef_full']

pcoefs = jnp.array([coef[0] for coef in pcoefs])
poly = Chebyshev(pcoefs)

# %%
U_sweep = jnp.linspace(0, U, 11)

# %%
solved_eigvals = [[vals.item() for vals in H0_eigvals_updated]]

def Wegstein_solver(Schur_complement, x0, subspace_eigvals_idx, E_cutoff=10**(-error), max_iter=100):

    def f(x):
        Schur = Schur_complement(x)
        sub_eigvals = jnp.linalg.eigvalsh(Schur)
        return sub_eigvals[subspace_eigvals_idx] + x
    
    # Initialize xn and fn
    xn = [x0[subspace_eigvals_idx], f(x0[subspace_eigvals_idx])]
    fn = [xn[1], f(xn[1])]    
    
    for i in range(1, max_iter):
        
        x_new = (xn[i-1]*fn[i] - xn[i]*fn[i-1]) / (xn[i-1] + fn[i] - xn[i] - fn[i-1])
        xn.append(x_new)
        fn.append(f(x_new))
        
        # If the energy difference is less than cutoff, the algorithm converge
        if abs(x_new - xn[i]) < E_cutoff:
            print(f"Converged in {i} iterations.")
            print(fn[-1])
            return fn[-1]
    
    print("Wegstein method did not converge within the maximum number of iterations.")
    print(fn[-1])   
    return fn[-1]


for i, UU in enumerate(U_sweep):
    # Skip the first iteration
    if i == 0:
        continue
    print('solve:', i)
    
    # Construct the Hamiltonian for the coulomb = U
    H = reduced_hubbard_model(U=float(UU), indices=reduced_H_indices)
    
    # Use binary search to solve the eigenvalues of different band
    solved_eigval = []
    for subspace_eigvals_idx in range(k):
        subspace_solved_eigval = Wegstein_solver(Schur_complement=lambda x: Schur_complement_qsp(H=H, E=x, init_eigvecs=H0_eigvecs_updated, degeneracy_idx=degeneracy_idx, dim=reduced_dim, poly=poly, kappa=kappa), 
                                                x0=solved_eigvals[-1], subspace_eigvals_idx=subspace_eigvals_idx)
        solved_eigval.append(subspace_solved_eigval)
    solved_eigvals.append(solved_eigval)
solved_eigvals = jnp.array(solved_eigvals).T
# Out:
# solve: 1
# Converged in 2 iterations.
# -11.071771589992284
# Converged in 2 iterations.
# -11.070989419468132
# Converged in 2 iterations.
# -11.070989419468008
# Converged in 2 iterations.
# -11.07098941946802
# Converged in 2 iterations.
# -11.070989419468189
# Converged in 2 iterations.
# -11.07074860094827
# Converged in 2 iterations.
# -11.07074860094842
# solve: 2
# Converged in 2 iterations.
# -10.95303694970003
# Converged in 2 iterations.
# -10.950300087688893
# Converged in 2 iterations.
# -10.950300087688795
# Converged in 2 iterations.
# -10.950300087689005
# Converged in 2 iterations.
# -10.950300087688838
# Converged in 2 iterations.
# -10.94937548282781
# Converged in 2 iterations.
# -10.949375482827726
# solve: 3
# Converged in 14 iterations.
# -10.842830355379604
# Converged in 16 iterations.
# -10.837437055104601
# Converged in 5 iterations.
# -10.837437055771948
# Converged in 13 iterations.
# -10.837437056284731
# Converged in 44 iterations.
# -10.83743705586824
# Converged in 5 iterations.
# -10.835446048821355
# Converged in 14 iterations.
# -10.835446048860296
# solve: 4
# Converged in 3 iterations.
# -10.740311858580466
# Converged in 13 iterations.
# -10.731902970506525
# Converged in 27 iterations.
# -10.731902969187004
# Converged in 13 iterations.
# -10.731902968957305
# Converged in 9 iterations.
# -10.73190296932658
# Converged in 5 iterations.
# -10.728523727157704
# Converged in 33 iterations.
# -10.728523726946962
# solve: 5
# Converged in 9 iterations.
# -10.644747306199783
# Converged in 12 iterations.
# -10.633207322566788
# Converged in 9 iterations.
# -10.633207322072286
# Converged in 6 iterations.
# -10.633207322606758
# Converged in 8 iterations.
# -10.633207322545632
# Converged in 41 iterations.
# -10.628176754053321
# Converged in 10 iterations.
# -10.628176754677916
# solve: 6
# Converged in 52 iterations.
# -10.555491943152024
# Converged in 19 iterations.
# -10.540873427243998
# Converged in 6 iterations.
# -10.540873427771057
# Converged in 32 iterations.
# -10.540873428167263
# Converged in 15 iterations.
# -10.54087342649071
# Converged in 3 iterations.
# -10.53398363882044
# Converged in 32 iterations.
# -10.533983638987676
# solve: 7
# Converged in 3 iterations.
# -10.471976966251752
# Converged in 29 iterations.
# -10.454443351534495
# Converged in 46 iterations.
# -10.454443351922857
# Converged in 3 iterations.
# -10.454443351616785
# Converged in 20 iterations.
# -10.454443351765729
# Converged in 19 iterations.
# -10.445537350750497
# Converged in 3 iterations.
# -10.445537350985267
# solve: 8
# Converged in 12 iterations.
# -10.393698462100339
# Converged in 6 iterations.
# -10.373481176177078
# Converged in 13 iterations.
# -10.373481177323924
# Converged in 40 iterations.
# -10.373481176045678
# Converged in 3 iterations.
# -10.373481176180688
# Converged in 5 iterations.
# -10.362448380151244
# Converged in 11 iterations.
# -10.362448386567594
# solve: 9
# Converged in 6 iterations.
# -10.320208288088903
# Converged in 3 iterations.
# -10.297574904992247
# Converged in 7 iterations.
# -10.297574905905432
# Converged in 3 iterations.
# -10.297574905423538
# Converged in 6 iterations.
# -10.297574904743945
# Converged in 6 iterations.
# -10.284346817173061
# Converged in 8 iterations.
# -10.284346816883957
# solve: 10
# Converged in 14 iterations.
# -10.251106484722001
# Converged in 17 iterations.
# -10.226337377859863
# Converged in 12 iterations.
# -10.22633737153015
# Converged in 3 iterations.
# -10.226337377923995
# Converged in 3 iterations.
# -10.22633737769541
# Converged in 15 iterations.
# -10.210883544474791
# Converged in 9 iterations.
# -10.210883545050923

# %%
for band in range(degeneracy_idx[0], degeneracy_idx[1] + 1):
    plt.plot(U_sweep_ED, H_eigvals_sweep[band], 'red')
for band in range(degeneracy_idx[0], degeneracy_idx[1] + 1):
    plt.plot(U_sweep, solved_eigvals[band], 'black', linestyle='dashed')

plt.plot(U_sweep_ED[0], H_eigvals_sweep[band][0], 'red', label='ED')
plt.plot(U_sweep[0], solved_eigvals[0, 0], 'black', linestyle='dashed', label='Wegstein')

plt.xlabel('U')
plt.ylabel('E')
plt.title(f'Eigenvalues vs U, {x_dimension}x{y_dimension}')
# plt.ylim(jnp.min(solved_eigvals) - 0.5, jnp.max(solved_eigvals) + 0.5)

plt.legend()
plt.show()

# %%
for i in range(7):
    print(solved_eigvals.T[-1, i]-H_eigvals_sweep.T[-1, i])
# Out:
# 3.4810767601811676e-09
# 0.0008757804676342573
# 0.000875786797340794
# 0.0008757804034953409
# 0.000875780632076939
# 2.1475007214277753e-05
# 2.1474431081358603e-05

# %% [markdown]
# ## $\Delta U = 4$

# %% [markdown]
# ## error $ = 10^{-3}$

# %%
kappa = 80
error = 3
file_name = f'coef_kappa{kappa}_error1e-{error}*'
file = glob.glob(file_name)
pcoefs = loadmat(file[0])
pcoefs = pcoefs['coef_full']

pcoefs = jnp.array([coef[0] for coef in pcoefs])
poly = Chebyshev(pcoefs)

# %%
U_sweep = jnp.linspace(0, U, 2)

# %%
solved_eigvals = [[vals.item() for vals in H0_eigvals_updated]]

def Wegstein_solver(Schur_complement, x0, subspace_eigvals_idx, E_cutoff=10**(-error), max_iter=100):

    def f(x):
        Schur = Schur_complement(x)
        sub_eigvals = jnp.linalg.eigvalsh(Schur)
        return sub_eigvals[subspace_eigvals_idx] + x
    
    # Initialize xn and fn
    xn = [x0[subspace_eigvals_idx], f(x0[subspace_eigvals_idx])]
    fn = [xn[1], f(xn[1])]    
    
    for i in range(1, max_iter):
        
        x_new = (xn[i-1]*fn[i] - xn[i]*fn[i-1]) / (xn[i-1] + fn[i] - xn[i] - fn[i-1])
        xn.append(x_new)
        fn.append(f(x_new))
        
        # If the energy difference is less than cutoff, the algorithm converge
        if abs(x_new - xn[i]) < E_cutoff:
            print(f"Converged in {i} iterations.")
            print(fn[-1])
            return fn[-1]
    
    print("Wegstein method did not converge within the maximum number of iterations.")
    print(fn[-1])   
    return fn[-1]


for i, UU in enumerate(U_sweep):
    # Skip the first iteration
    if i == 0:
        continue
    print('solve:', i)
    
    # Construct the Hamiltonian for the coulomb = U
    H = reduced_hubbard_model(U=float(UU), indices=reduced_H_indices)
    
    # Use binary search to solve the eigenvalues of different band
    solved_eigval = []
    for subspace_eigvals_idx in range(k):
        subspace_solved_eigval = Wegstein_solver(Schur_complement=lambda x: Schur_complement_qsp(H=H, E=x, init_eigvecs=H0_eigvecs_updated, degeneracy_idx=degeneracy_idx, dim=reduced_dim, poly=poly, kappa=kappa), 
                                                x0=solved_eigvals[-1], subspace_eigvals_idx=subspace_eigvals_idx)
        solved_eigval.append(subspace_solved_eigval)
    solved_eigvals.append(solved_eigval)
solved_eigvals = jnp.array(solved_eigvals).T
# Out:
# solve: 1
# Converged in 2 iterations.
# -10.251125196825177
# Converged in 2 iterations.
# -10.225853466125324
# Converged in 2 iterations.
# -10.225853466125336
# Converged in 2 iterations.
# -10.225853466125319
# Converged in 2 iterations.
# -10.225853466125272
# Converged in 2 iterations.
# -10.211520060410882
# Converged in 2 iterations.
# -10.211520060410907

# %%
for band in range(degeneracy_idx[0], degeneracy_idx[1] + 1):
    plt.plot(U_sweep_ED, H_eigvals_sweep[band], 'red')
for band in range(degeneracy_idx[0], degeneracy_idx[1] + 1):
    plt.plot(U_sweep, solved_eigvals[band], 'black', linestyle='dashed')

plt.plot(U_sweep_ED[0], H_eigvals_sweep[band][0], 'red', label='ED')
plt.plot(U_sweep[0], solved_eigvals[0, 0], 'black', linestyle='dashed', label='Wegstein')

plt.xlabel('U')
plt.ylabel('E')
plt.title(f'Eigenvalues vs U, {x_dimension}x{y_dimension}')
# plt.ylim(jnp.min(solved_eigvals) - 0.5, jnp.max(solved_eigvals) + 0.5)

plt.legend()
plt.show()

# %%
for i in range(7):
    print(solved_eigvals.T[-1, i]-H_eigvals_sweep.T[-1, i])
# Out:
# -1.870862209862878e-05
# 0.0013596922021736901
# 0.0013596922021541502
# 0.0013596922021719138
# 0.0013596922022145463
# -0.0006150409288760983
# -0.0006150409289027436
